# %%
import os
import re

# %%
template = """
survey {surveyName} -title {surveyName} -entrance {entranceStation}
{Centrelines}
endsurvey
"""

# %%
centreline_template = """
    centreline
    {surveyDate}
    {surveyTeams}
    \tunits length meters
    \tunits compass clino degrees
    {dataheader}
    {data}
    \tdata dimensions station left right up down
    {lrud}
    endcentreline
"""

# %%
dive_topo = "\tdata diving to todepth from fromdepth tape compass"
normal_topo = "\tdata normal from to tape compass clino"

# %%
def writeDate(explodate):
    try:
        month = explodate[3:5]
        year = explodate[-2:]
        if int(year) < 50:
            year4digits = '20'+ year 
    
        day = explodate[:2]
    
        date =  'date {}.{}.{}\n'.format(year4digits,month,day)
        
    except:
        date = ''
        
    return date

# %%
def writeSurveyors(surveyors):
    lines = ""
    for surveyor in surveyors:
        if surveyor != 'et':
            lines+= '\t team "{}"\n'.format(surveyor)
        
    return lines

# %%
def getData(data,s,e):
    style = data[s-1] # either 'normal' or 'diving'
    stn1 = []
    stn2 = []
    fromdepth = []
    todepth = []
    tape = []
    compass = []
    clino = []
    left = []
    right = []
    up = []
    down = []
    print(style)
    for c,l in enumerate(data[s+1:e]):
        # check the station 1 name.

        data_line = l.split(' ')
        data_line[:] = [x for x in data_line if x]
        
        if len(data_line) > 9:
            if data_line[0] =='*':
                previous = data[s+c].split(' ')
                previous[:] = [x for x in previous if x]

                previous_stn = previous[1]
                
                data_line[0] = previous_stn
            if 'Prof' not in style:
                for key,val in enumerate((stn1,stn2,tape,compass,clino,left, right, up, down)):
                    val.append(data_line[key])
                    
            else:
                print('found diving data')
                for key,val in enumerate((stn2,todepth,stn1,fromdepth,tape,compass,left, right, up, down)):
                    val.append(data_line[key])
    
    if 'Prof' not in style:   
        formatted_data =  (stn1,stn2,tape,compass,clino,left,right,up,down)
    else:
        formatted_data = (stn2,todepth,stn1,fromdepth,tape,compass,left, right, up, down)
    return formatted_data

# %%
def FindEntrancestn(data):
    for c,l in enumerate(data):
        if 'Entree' in l:
            entrance_stations = re.findall(r"(?<=Entree\s).+",l)
    return entrance_stations

# %%
def returnCentrelineparams(data):
    # find the parameters of the file.
    start,end = [],[]
    survey_dates = []
    surveyor_groups = []
    
    for c,l in enumerate(data):
        if 'Param' in l:
            if len(start) >= 1:
                end.append(c-1)
            start.append(c+1)
            
                
            explodate = re.findall(r"\d\d.\d\d.\d\d", l)
            if len(explodate) == 0:
                survey_dates.append('')
            else:
                survey_dates.append(re.sub(r"-",".",explodate[0]))
            tp = re.findall(r"(?<=Topo réalisée par )[\w+\s]*",l)
            if len(tp) == 0:
                surveyor_groups.append('')
            else:
                surveyor_groups.append(tp[0].split(' '))
        elif 'Configuration' in l:
            end.append(c-1)
        
    
    return surveyor_groups,survey_dates,start,end

# %%
def cleanNames(string):
    
    string = string.encode('utf-8').replace(b'o\xcc\x82',b'o').decode('utf-8')
    string = string.encode('utf-8').replace(b'e\xc3\xa9',b'e').decode('utf-8')
    string = string.encode('utf-8').replace(b'e\xc3\xa8',b'e').decode('utf-8')
    string = string.encode('utf-8').replace(b'\xc3\x81',b'').decode('utf-8')
    string = string.encode('utf-8').replace(b'\xcc\x81',b'').decode('utf-8')
    
    string.replace('\s','_')
    return string

# %%
def writeCentreline(data,start,end,surveyor_group,survey_date):
    shot = "{stn1}\t{stn2}\t{tape}\t{compass}\t{clino}\n\t\t"
    dive_shot = "{to}\t{todepth}\t{from}\t{fromdepth}\t{tape}\t{compass}"
    station_dims = "{stn}\t{left}\t{right}\t{up}\t{down}\n\t\t"
    data_lines = ""
    lrud_lines = ""
    
    if 'Prof' not in data[start-1]:
        datastyle = 'normal'
        stn1,stn2,tape,compass,clino,left,right,up,down = getData(data,start,end)


        header = normal_topo
        print(len(stn1))
        for c in range(len(stn1)):

            data_line = shot.format(stn1=stn1[c],
                        stn2=stn2[c],
                        tape=tape[c],
                        compass=compass[c],
                        clino=clino[c])
            data_lines+= '\t'+data_line
            
            lrud_line =  station_dims.format(stn=stn1[c],
                            left=left[c],
                            right=right[c],
                            up=up[c],
                            down=down[c])
            
            lrud_lines+= '\t'+re.sub(r"\*","-",lrud_line)
            
    elif 'Prof' not in data[start-1]:
        print('found diving data')
        datastyle = 'diving'
        header = dive_topo
        print(header)
 
        stn2,todepth,stn1,fromdepth,tape,compass,left,right,up,down = getData(data,start,end)
        
        for c in range(len(stn1)):
            data_line = shot.format(stn2=stn2[c],
                                todepth=todepth[c],
                                stn1=stn1[c],
                                fromdepth=fromdepth[c],
                                tape=tape[c],
                                compass=compass[c])
            data_lines+= '\t'+data_line
            
            lrud_line =  station_dims.format(stn=stn1[c],
                            left=left[c],
                            right=right[c],
                            up=up[c],
                            down=down[c])
            
            lrud_lines+= '\t'+re.sub(r"\*","-",lrud_line)
    else:
        header = normal_topo

            
    surveyDate = writeDate(survey_date)
    surveyTeams = writeSurveyors(surveyor_group)
    print(header)
    return centreline_template.format(surveyTeams = surveyTeams,
                                      surveyDate = surveyDate ,
                                      data = data_lines,
                                      lrud=lrud_lines,
                                     dataheader=header)

# %%
def cleanUpNamespace(string):
    string = string.encode('utf-8')
    string = string.decode('utf-8')
    string  = re.sub('é','e',string)
    string  = re.sub(r'è','e',string)
    string  = re.sub(r'ô','o',string)
    string  = re.sub(r'â','a',string)
    string  = re.sub(r'ä','a',string)
    string  = re.sub(r'ê','e',string)
    string  = re.sub(r'ç','c',string)
    
    return string

# %%
def writeTemplate(filepath, new_filepath,cave_name):

    with open (filepath,'r', encoding='latin-1') as f1:
        data = f1.readlines()
        f1.close() 
    
    surveyor_groups,survey_dates,starts,ends = returnCentrelineparams(data)
    
    centrelines = ""
    
    entrance = FindEntrancestn(data)
    for start,end,surveyor_group,survey_date in zip(starts,ends,surveyor_groups,survey_dates):
        
        centrelines+= "\n"+writeCentreline(data,start,end,surveyor_group,survey_date)
    
    
    TEMPLATE = template.format(surveyName=cave_name,
                               Centrelines =centrelines,
                               entranceStation =entrance[0])
    print(new_filepath)
    with open('{}.th'.format(new_filepath[:-4]),'w+',encoding='utf-8') as f:
        f.write(TEMPLATE)
        f.close()

# %%
names =[]
for root, dirs, files in os.walk("../../Americas/TOPOGRAPHIES/", topdown=False):
    for name in files:
        if 'tro' in name and ('._' not in name):
            fp = os.path.join(root, name)
            cave_name = cleanNames(name)[:-4].replace(' ','_')
            writeTemplate(fp, os.path.join(root,cleanNames(name)), cave_name)
    #for name in dirs:
        #print(os.path.join(root, name))
# Out:
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 8
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/GB Trou 1/GB Trou 1.tro
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Cueva des erizos/Cueva des erizos.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Explorer et topographier le 17 fev 2017 par Yannick Serge et José;
#
# 50
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Grotte des dauphins/Grotte des dauphins.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo 20/01/2017, Arnauld, Joel;
#
# 28
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/PE3bis_Lagrimas/PE3bis_Lagrimas.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 7
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/GB Trou 4 - Gouffre du Ziploc/GB Trou 4 - Gouffre du Ziploc.tro
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Résurgence Sud du Brazo de los Puertos/Resurgence Sud du Brazo de Los Puertos.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Madame Café Denis et Lionel. topo levé le 3-02-2017;
#
# 6
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Madame Café/Topographie1.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,104,32 ;Topographie du siphon vers l'entrée le 28 janvier 2017, Vincent Lignier et Richard Maire.;
#
# 7
# 	data normal from to tape compass clino
# 	data normal from to tape compass clino
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep 255,104,32 ;Topographie du 10 février 2017, David et Yann, jonction entre les deux entrées;
#
# 20
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Las duchas de San Pedro/Las duchas de San Pedro.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 5
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/GB 08 02 01/GB 08 02 01.tro
# 	data normal from to tape compass clino
# 	data normal from to tape compass clino
# 	data normal from to tape compass clino
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Exsurg_Chinoise/Topo ExsurgChinoise.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 26
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/pe2_ombligo_de _la_madre/pe2_ombligo_de_la_madre.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo Arnauld, JeanPhi, 31/01/2017. du haut du P50 vers sortie.;
#
# 15
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Gouffre_Chameau/Gouffre_Chameau.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;PORCHE DU HARICOT EXPLO, ESCALADE ET TOPO LE 17 FEV 2017 PAR ANGEL ET ANTO;
#
# 24
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/L_escalade du haricot/haricot.tro
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Resurgencia de la Bahía Blanca/Resurgencia de la Bahia Blanca.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;15-02-2017, explo y topo: Anton, Buldo,Natalia,Richard y Angel;
#
# 28
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Cueva del Cabo Vertical/cuevacabovertical.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topographie le 06 fvrier 2017, Buldo, Natalia, Anel, Franck. Topo de l'entrée vers le fond.;
#
# 54
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Explo et topographie du 08 février 2017, Angel, Buldo et Natalia.;
#
# 52
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevé des stations 1000 à 1039 réalisée par Yannick Campan et Thomas Fischer le 11/02/2017;
#
# 49
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep 0,0,255 ;Topographie du 11 février 2017, Yann, Natalia et Franck.;
#
# 22
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevés topographiques réalisés par Natalia Morata, Yannick Campan et Thomas Fischer le 12/02/2017;
#
# 36
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep 0,255,0 ;Topographie du 12 février 2017, Franck et Yann;
#
# 61
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevés topographiques effectués par David et Thomas le 22/02/2017;
#
# 60
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Cueva de la Punta Blanca/OLD/2017_02_23_Cueva de la Punta Blanca.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topographie le 06 fvrier 2017, Buldo, Natalia, Anel, Franck. Topo de l'entrée vers le fond.;
#
# 54
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Explo et topographie du 08 février 2017, Angel, Buldo et Natalia.;
#
# 52
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevé des stations 1000 à 1039 réalisée par Yannick Campan et Thomas Fischer le 11/02/2017;
#
# 49
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep 0,0,255 ;Topographie du 11 février 2017, Yann, Natalia et Franck.;
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevés topographiques réalisés par Natalia Morata, Yannick Campan et Thomas Fischer le 12/02/2017;
#
# 36
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep 0,255,0 ;Topographie du 12 février 2017, Franck et Yann;
#
# 61
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevés topographiques effectués par David et Thomas le 22/02/2017;
#
# 58
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Cueva de la Punta Blanca/OLD/Cueva de la Punta Blanca.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topographie le 06 fvrier 2017, Buldo, Natalia, Anel, Franck. Topo de l'entrée vers le fond.;
#
# 54
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Explo et topographie du 08 février 2017, Angel, Buldo et Natalia.;
#
# 52
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevé des stations 1000 à 1039 réalisée par Yannick Campan et Thomas Fischer le 11/02/2017;
#
# 49
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep 0,0,255 ;Topographie du 11 février 2017, Yann, Natalia et Franck.;
#
# 23
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevés topographiques réalisés par Natalia Morata, Yannick Campan et Thomas Fischer le 12/02/2017;
#
# 36
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep 0,255,0 ;Topographie du 12 février 2017, Franck et Yann;
#
# 61
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Relevés topographiques effectués par David et Thomas le 22/02/2017;
#
# 59
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Cueva de la Punta Blanca/2017_02_24_Cueva de la Punta Blanca.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Les Porches de la Coulée Blanche - Explo du 13/02/2017 par Yannick et Yann;
#
# 17
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;topo et meusure le 16 fev 2017 yannick et anto;
#
# 19
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Porches de la coulée blanche/Topographie Porches de la coulee blanche.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 19
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;du fond vers l entree;
#
# 13
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie les 15 et 17/02 par Lucas, Yann et Thomas;
#
# 86
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 64
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Exploration le 17/02/17 par Yann, Thomas et Lucas;
#
# 95
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/gouffre du casque/topo_gouffre_Casque.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 19
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;du fond vers l entree;
#
# 13
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie les 15 et 17/02 par Lucas, Yann et Thomas;
#
# 86
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 64
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Exploration le 17/02/17 par Yann, Thomas et Lucas;
#
# 95
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/gouffre du casque/topo_gouffre_Casque - Copie.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 19
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;du fond vers l entree;
#
# 13
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie les 15 et 17/02 par Lucas, Yann et Thomas;
#
# 86
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std
#
# 64
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Exploration le 17/02/17 par Yann, Thomas et Lucas;
#
# 39
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/gouffre du casque/topo_gouffre_Casque_sans_affluent.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Affluent exploré par Thomas, Yann et Lucas le 17/02/17;
#
# 57
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/gouffre du casque/Topo_affluent_gouffre_casque.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie Arnauld, Joel, le 27/01;
#
# 47
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo Arnauld Laurence, le 28/01, du siphon au haut du P20;
#
# 5
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 127,255,212 ;Topo des galeries labyrinthiques dans le secteur du tobogan de terre. Topo Laurent et Steph 31 janv 2017. Arrêt topo au point 198 sur carrefour de la grande diaclase;
#
# 46
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,255,0 ;Topo de la zone d'entrée et des trois porches. Laurent et Steph 31 janv 2017;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,0,0 ;Cheminement externe depuis bloc E6 jusquà la vasque et la mer. Laurent et Stephane, 31 jan 2017. Soustraire 100 m au développement car c'est en externe;
#
# 15
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,104,32 ;Equipe topo Buldo, José, Georges, Natalia - 31 janvier 2017. Jonction avec le point topo du siphon, douteuse...;
#
# 17
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,0,255 ;Topo Steph et Laurent - 2 fev 2017;
#
# 51
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;visées vers le fond, largeur au point de depart, 02/02/2017, Buldo, Lolo,Jean-Marc, Florian, point d'acroche 300;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 50,205,50 ;Topo 1iere galerie gauche laissée par Stéphane le ? Départ à partir du point 193 (jonction le meme jour avec Stéphane parti du second départ à gauche laissé la fois d'avant);
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topographie du 19/02 par Yannick et Anthony depuis le fond vers le Y19.;
#
# 12
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 18 février, Natalia, Buldo et Angel. Les étiquettes sous terre marqués A0, etc correspondent à 2000, etc sur la topo.;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Toporaphie du 19 février 2017, Lionel et Franck;
#
# 27
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Explo/Topo du 19/02/17 par Anto et Yann;
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 20 février 2017, Yann et Yannick.;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 20 février, Yannick, Gelo et Franck.;
#
# 11
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Grotte des 3 entrées/grotte des 3 entrees mdd 2017_v4.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie Arnauld, Joel, le 27/01;
#
# 47
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo Arnauld Laurence, le 28/01, du siphon au haut du P20;
#
# 5
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 127,255,212 ;Topo des galeries labyrinthiques dans le secteur du tobogan de terre. Topo Laurent et Steph 31 janv 2017. Arrêt topo au point 198 sur carrefour de la grande diaclase;
#
# 46
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,255,0 ;Topo de la zone d'entrée et des trois porches. Laurent et Steph 31 janv 2017;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,0,0 ;Cheminement externe depuis bloc E6 jusquà la vasque et la mer. Laurent et Stephane, 31 jan 2017. Soustraire 100 m au développement car c'est en externe;
#
# 15
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,104,32 ;Equipe topo Buldo, José, Georges, Natalia - 31 janvier 2017. Jonction avec le point topo du siphon, douteuse...;
#
# 17
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,0,255 ;Topo Steph et Laurent - 2 fev 2017;
#
# 51
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;visées vers le fond, largeur au point de depart, 02/02/2017, Buldo, Lolo,Jean-Marc, Florian, point d'acroche 300;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 50,205,50 ;Topo 1iere galerie gauche laissée par Stéphane le ? Départ à partir du point 193 (jonction le meme jour avec Stéphane parti du second départ à gauche laissé la fois d'avant);
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topographie du 19/02 par Yannick et Anthony depuis le fond vers le Y19.;
#
# 12
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 18 février, Natalia, Buldo et Angel. Les étiquettes sous terre marqués A0, etc correspondent à 2000, etc sur la topo.;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Toporaphie du 19 février 2017, Lionel et Franck;
#
# 27
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Explo/Topo du 19/02/17 par Anto et Yann;
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 20 février 2017, Yann et Yannick.;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 20 février, Yannick, Gelo et Franck.;
#
# 11
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 22 février, Natalia,Buldo y Angel;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 22 février, Lionel et Denis;
#
# 7
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Grotte des 3 entrées/grotte des 3 entrees mdd 2017_v6.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie Arnauld, Joel, le 27/01;
#
# 47
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo Arnauld Laurence, le 28/01, du siphon au haut du P20;
#
# 5
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 127,255,212 ;Topo des galeries labyrinthiques dans le secteur du tobogan de terre. Topo Laurent et Steph 31 janv 2017. Arrêt topo au point 198 sur carrefour de la grande diaclase;
#
# 46
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,255,0 ;Topo de la zone d'entrée et des trois porches. Laurent et Steph 31 janv 2017;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,0,0 ;Cheminement externe depuis bloc E6 jusquà la vasque et la mer. Laurent et Stephane, 31 jan 2017. Soustraire 100 m au développement car c'est en externe;
#
# 15
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,104,32 ;Equipe topo Buldo, José, Georges, Natalia - 31 janvier 2017. Jonction avec le point topo du siphon, douteuse...;
#
# 17
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,0,255 ;Topo Steph et Laurent - 2 fev 2017;
#
# 51
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;visées vers le fond, largeur au point de depart, 02/02/2017, Buldo, Lolo,Jean-Marc, Florian, point d'acroche 300;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 50,205,50 ;Topo 1iere galerie gauche laissée par Stéphane le ? Départ à partir du point 193 (jonction le meme jour avec Stéphane parti du second départ à gauche laissé la fois d'avant);
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topographie du 19/02 par Yannick et Anthony depuis le fond vers le Y19.;
#
# 12
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 18 février, Natalia, Buldo et Angel. Les étiquettes sous terre marqués A0, etc correspondent à 2000, etc sur la topo.;
#
# 16
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Grotte des 3 entrées/grotte des 3 entrees mdd 2017_v3.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie Arnauld, Joel, le 27/01;
#
# 47
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo Arnauld Laurence, le 28/01, du siphon au haut du P20;
#
# 5
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 127,255,212 ;Topo des galeries labyrinthiques dans le secteur du tobogan de terre. Topo Laurent et Steph 31 janv 2017. Arrêt topo au point 198 sur carrefour de la grande diaclase;
#
# 46
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,255,0 ;Topo de la zone d'entrée et des trois porches. Laurent et Steph 31 janv 2017;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,0,0 ;Cheminement externe depuis bloc E6 jusquà la vasque et la mer. Laurent et Stephane, 31 jan 2017. Soustraire 100 m au développement car c'est en externe;
#
# 15
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 255,104,32 ;Equipe topo Buldo, José, Georges, Natalia - 31 janvier 2017. Jonction avec le point topo du siphon, douteuse...;
#
# 17
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 0,0,255 ;Topo Steph et Laurent - 2 fev 2017;
#
# 51
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;visées vers le fond, largeur au point de depart, 02/02/2017, Buldo, Lolo,Jean-Marc, Florian, point d'acroche 300;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr 50,205,50 ;Topo 1iere galerie gauche laissée par Stéphane le ? Départ à partir du point 193 (jonction le meme jour avec Stéphane parti du second départ à gauche laissé la fois d'avant);
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topographie du 19/02 par Yannick et Anthony depuis le fond vers le Y19.;
#
# 12
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 18 février, Natalia, Buldo et Angel. Les étiquettes sous terre marqués A0, etc correspondent à 2000, etc sur la topo.;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Toporaphie du 19 février 2017, Lionel et Franck;
#
# 27
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Explo/Topo du 19/02/17 par Anto et Yann;
#
# 25
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 20 février 2017, Yann et Yannick.;
#
# 18
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topographie du 20 février, Yannick, Gelo et Franck.;
#
# 11
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Grotte des 3 entrées/grotte des 3 entrees mdd 2017_v5.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topo réalisée par Lionel et Joël. Exploration le 30.01.17 par Denis Joël et Lionel. Disto x. GPS : GB 30.01.17 01 ;
#
# 9
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Ayayemal/Ayayemal.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo Arnauld, Laurence, le 31/1/2017. Du fond vers sortie;
#
# 11
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Cueva_los_Gringos/Cueva_los_Gringos.tro
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Arr Std ;Topo réalisée par Lionel et Joël. Disto x. GPS : GB 30.01.17.02;
#
# 9
# 	data normal from to tape compass clino
# Param Deca Degd Clino Degd 0.0000 Dir,Dir,Dir Dep Std ;Topo réalisée par Lucas et Yann. Disto X. 07-02-17;
#
# 5
# 	data normal from to tape compass clino
# ../../Americas/TOPOGRAPHIES/Ayayebo/Ayayebo.tro
