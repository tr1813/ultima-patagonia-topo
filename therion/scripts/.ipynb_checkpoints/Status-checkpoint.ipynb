# %%
import os
from os.path import isfile, join, dirname, abspath
import sys
import re
import argparse
import shutil
import subprocess
import tempfile
import pandas as pd

import shapefile
from json import dumps

# %%
reader = shapefile.Reader("../data/gis/stations3d.shp")
fields = reader.fields[1:]
field_names = [field[0] for field in fields]
buffer = []
for sr in reader.shapeRecords():
    atr = dict(zip(field_names, sr.record))
    # filter by centerline
    
    if 'ENT' in atr['_NAME']:      
        print(atr)
        geom = sr.shape.__geo_interface__
        buffer.append(dict(type="Feature", geometry=geom, properties=atr))
    # write the GeoJSON file

#geojson = open("../data/gis/points_fixes.js", "w")
#geojson.write("var points_fixes = \n")
#geojson.write(dumps({"type": "FeatureCollection", "features": buffer}, indent=2) + "\n")
#geojson.close()

# %%
THERION_STATUS_LIST = [(feature['properties']['_NAME'],feature['properties']['_COMMENT'],feature['geometry']['coordinates'][0],feature['geometry']['coordinates'][1]) for feature in buffer]

# %%
## read the cavity synthesis
synthese_cavites = pd.read_csv("../data/cadastre/UP_MDD_DDA_Temp_synthese_Cavites.csv")

# %%
synthese_cavites[['X (UTM 18 Sud)','Y (UTM 18 Sud)','NomCadastre']]
# Out:
#      X (UTM 18 Sud)  Y (UTM 18 Sud)         NomCadastre
# 0          473667.0       4416955.0   LeMasqueEtLaPlume
# 1          469367.0       4421504.0     AbrigoDelViento
# 2          469510.0       4421914.0    SumideroPiquante
# 3          470302.0       4421526.0    GouffreAguilucho
# 4          470298.0       4421336.0  ExsurgencePicaflor
# ..              ...             ...                 ...
# 444        473093.0       4426314.0    PerteDesSabliers
# 445        479668.0       4427696.0     ResurgenceLobos
# 446        479379.0       4428572.0      SystemeCondors
# 447        479379.0       4428572.0      SystemeCondors
# 448        479379.0       4428572.0   GouffrePetitCreux
#
# [449 rows x 3 columns]

# %%
# index

CADASTRE_NUMBER = []
for element in synthese_cavites[['X (UTM 18 Sud)','Y (UTM 18 Sud)','NomCadastre']].iterrows():
    LINE = []
    LINE.append(element[1][2])
    for fixed_point in THERION_STATUS_LIST:
        try:
            if int(fixed_point[2]) == int(element[1][0]):
                if int(fixed_point[3]) == int(element[1][1]):
                    print(fixed_point[0],element[1][2])
                    LINE.append(fixed_point[0])

        except ValueError:
            #print("coordinates are likely NaN")
            pass
    CADASTRE_NUMBER.append(LINE)
# Out:
# ENT_213001 LeMasqueEtLaPlume
# ENT_211001 AbrigoDelViento
# ENT_211002 SumideroPiquante
# ENT_211003 GouffreAguilucho
# ENT_211004 ExsurgencePicaflor
# ENT_211006 SimaDelCol
# ENT_211007 MD-BDGS01
# ENT_211008 MD-BDGS02
# ENT_211009 MD-BDGS03
# ENT_211010 MD-BDGS04
# ENT_211011 MD-BDG05
# ENT_209001 PleinCintre
# ENT_209002 EmergenceBarillet
# ENT_209003 GouffreDeLaGachette
# ENT_209004 Perte de l'Acharné
# ENT_209005 Perte n° 18
# ENT_209006 ResurgenceDeLaPlage
# ENT_209007 GrotteEvier
# ENT_209008 BobLEponge
# ENT_209009 CuevaGringa
# ENT_208001 Cueva10H10
# ENT_205001 AbriCotier
# ENT_208002 Résurgence 9 plage de la Baleine
# ENT_208003 Grotte20PlageDeLaBaleine
# ENT_205002 AbriDuCerfeuil
# ENT_206001 CuevaAyayema
# ENT_206002 GrotteDuDyke
# ENT_205003 CuevaLaBas
# ENT_205004 PerteDesDents
# ENT_205005 SumideroJuanito
# ENT_205006 CuevaArdilla
# ENT_205007 PozoEnBosque
# ENT_205033 PozoEnBosque
# ENT_205008 Pozo 2 en Caliza
# ENT_205032 Pozo 2 en Caliza
# ENT_205009 Pozo 1 en Caliza
# ENT_205034 Pozo 1 en Caliza
# ENT_205010 MD-SOU01
# ENT_205011 MD-SOU02
# ENT_209010 DolineCalafate
# ENT_106002 CuevaNoTime
# ENT_106003 CuevaNoTime
# ENT_106005 CuevaNoTime
# ENT_106002 ResurgenceNoTime
# ENT_106003 ResurgenceNoTime
# ENT_106005 ResurgenceNoTime
# ENT_105001 CuevaRapido1
# ENT_105002 CuevaRapido1
# ENT_105001 CuevaRapido2
# ENT_105002 CuevaRapido2
# ENT_106004 CuevaNutria
# ENT_106002 Porche
# ENT_106003 Porche
# ENT_106005 Porche
# ENT_106006 Grotte
# ENT_102001 Porche
# ENT_109001 TroisPorches
# ENT_109002 TroisPorches
# ENT_107001 CuevaDesLosPescadores
# ENT_201001 Resurgence2DuCanyon
# ENT_212001 GrotteDeTarlton
# ENT_212002 TAR01
# ENT_212003 TAR02
# ENT_212004 TAR03
# ENT_212005 TAR04
# ENT_212006 TAR05
# ENT_205012 PerteInattendue
# ENT_205013 PerteAmbree
# ENT_205014 porche
# ENT_205015 PerteFaille
# ENT_205016 sortie traversée
# ENT_205017 Trou serrure entrée
# ENT_205018 grotte jef
# ENT_205019 Aven grd diam
# ENT_205020 perte 2
# ENT_205021 PerteDesQuatreChampignons
# ENT_204001 GouffreGazelle
# ENT_204002 EvequeCauchon
# ENT_205022 JamesBonde
# ENT_204003 GrotteFaussePucelle
# ENT_205023 PerteDuJump
# ENT_211012 GrotteGrandeSoeur
# ENT_205024 FailleDuCoinceur
# ENT_205025 IgueDuPlouc
# ENT_205026 CuevaDeLaFinDeMatinas
# ENT_204001 GouffreAlouette
# ENT_203001 PerteDuCoypo
# ENT_203002 GouffreFelin
# ENT_203003 PuitsDuBourdon
# ENT_203004 GrosTrou
# ENT_203005 Résurgence
# ENT_203006 Résurgence
# ENT_203007 Résurgence
# ENT_204005 TrouDesCanelures
# ENT_204006 Perte1
# ENT_203008 Aven C301
# ENT_204007 Perte2
# ENT_203009 Aven
# ENT_201002 LaRabasse3
# ENT_201027 LaRabasse3
# ENT_201003 Secteur Barros Luco
# ENT_201004 LaRabasse1
# ENT_201030 LaRabasse1
# ENT_201005 Cueva3
# ENT_201006 Cueva7
# ENT_201007 Cueva1
# ENT_201008 Cueva11
# ENT_201009 CuevaDuTelephone
# ENT_201010 Cueva8
# ENT_201011 cueva101
# ENT_201012 TrouDuMarteau
# ENT_201033 TrouDuMarteau
# ENT_201013 LaRabasse2
# ENT_201028 LaRabasse2
# ENT_201014 cueva102
# ENT_201015 Cueva104
# ENT_201016 Cueva10
# ENT_201017 Secteur Barros Luco
# ENT_201018 Cueva2
# ENT_201019 Cueva105
# ENT_201003 Secteur Barros Luco
# ENT_201021 Secteur Barros Luco
# ENT_201022 Cueva12
# ENT_201023 Cueva5
# ENT_201024 Cueva13
# ENT_201025 Secteur Barros Luco
# ENT_201026 PorcheBaleine
# ENT_201080 Porche1
# ENT_203010 Porche1
# ENT_201002 C4T2
# ENT_201027 C4T2
# ENT_201013 C4T3
# ENT_201028 C4T3
# ENT_201029 Cueva4
# ENT_201004 C4T1
# ENT_201030 C4T1
# ENT_201031 C3
# ENT_201032 C4Cueva6
# ENT_201012 C4Cueva 9
# ENT_201033 C4Cueva 9
# ENT_201034 C4SansNom10
# ENT_201046 C4SansNom10
# ENT_201035 C4SansNom9
# ENT_201049 C4SansNom9
# ENT_201036 C4Nfissure0
# ENT_201037 C4SansNom8
# ENT_201038 C4SansNom7
# ENT_201039 C4SansNom6
# ENT_201040 C5Cueva2
# ENT_201050 C5Cueva2
# ENT_201041 C4SansNom1
# ENT_201042 C4SansNom4
# ENT_201043 C5Cueva3
# ENT_201048 C5Cueva3
# ENT_201044 C4SansNom3
# ENT_201045 C5 Cueva1
# ENT_201034 CuevaDeLaCasquette
# ENT_201046 CuevaDeLaCasquette
# ENT_201047 Champignon
# ENT_201043 GouffreDuColibri
# ENT_201048 GouffreDuColibri
# ENT_201035 TrouDeLaPlaquette
# ENT_201049 TrouDeLaPlaquette
# ENT_201040 PorcheDuSonnar
# ENT_201050 PorcheDuSonnar
# ENT_203011 AbriDuGazon
# ENT_205027 AbriGite
# ENT_204008 GrotteDuRapace
# ENT_205028 GrotteDuSud
# ENT_204009 GrotteDeLOursin
# ENT_205029 CuevaDeLaMadre
# ENT_205030 Porche
# ENT_203012 GrotteDuNord
# ENT_209011 GouffreDeLaDetente
# ENT_209012 Aven
# ENT_209013 Aven
# ENT Gouffre36
# ENT_211013 Gouffre36
# ENT_211014 GouffreDesMousquetaires
# ENT_211015 GouffreDeLArche
# ENT_211016 GouffreALaTeteDOurs
# ENT_211017 Aven
# ENT_211018 GrotteDeLobosSecos
# ENT_211019 GrotteMarion
# ENT_211020 MeandreDesSables
# ENT_211021 GrotteDeLaConduite
# ENT_211022 CuevaDelAgua
# ENT_211023 AvenDeLaTraverse
# ENT_211024 GrotteDuNomade
# ENT_211025 GrotteFilostik
# ENT_211026 PorcheDeLaMadre2
# ENT_211027 Aven
# ENT_211028 Abri3
# ENT_211029 Aven
# ENT_211030 GrandAvenTriple
# ENT_211031 PerteEnsablée
# ENT_211032 Cueva1
# ENT_211033 Porche
# ENT_211034 AVEN ?
# ENT_211035 Aven
# ENT_211036 LobosMatos
# ENT_211037 aven
# ENT_211038 Aven
# ENT_211039 aven
# ENT_211040 Aven
# ENT_211041 Cueva5
# ENT_211042 Cueva6
# ENT_211043 Perte1Lobos
# ENT_205031 GrotteAudeline
# ENT_211044 PerteDesLobos
# ENT_211049 PerteDesLobos
# ENT_211045 ElCuloDeLaMadre
# ENT_211046 LaGrotte
# ENT_211047 IgueDeDob
# ENT_211048 GrottePetiteSoeur
# ENT_211044 PuitsOctopus
# ENT_211049 PuitsOctopus
# ENT_209014 GouffreDuKit
# ENT_209015 GouffreCumpleAnos
# ENT_209016 LaMarmotte
# ENT_209017 AvenKinka4
# ENT_209018 Perte3
# ENT_209019 AvenKinka3
# ENT_209020 Aven
# ENT_209035 Aven
# ENT_209021 Aven
# ENT_209022 Aven -20
# ENT_209023 Gouffre1
# ENT_209024 AvenKinka2
# ENT_209025 AvenKinka1
# ENT_209026 Aven non descendu
# ENT_209027 Aven
# ENT_209028 Aven
# ENT_209029 GrandAvenPerte
# ENT_209030 TROUA
# ENT_209031 GrandeDolinePerte
# ENT_208004 Aven
# ENT_208005 Aven
# ENT_209032 Aven
# ENT_205008 Sou33
# ENT_205032 Sou33
# ENT_205007 Sou30
# ENT_205033 Sou30
# ENT_205009 Sou31
# ENT_205034 Sou31
# ENT_205035 Porche
# ENT_205036 Aven
# ENT_205037 GrotteSueno
# ENT_304001 PerteDeLaSucriere
# ENT_304002 OjoDelDiablo
# ENT_304003 PerteDeLaSucriereInferieure
# ENT_303001 Trou 1 sur 3eme bloc calcaire
# ENT_304004 PerteCol1
# ENT_303002 PerteDesPortesDAbraham
# ENT_303003 CuevaNutria
# ENT_304005 TC1
# ENT_304006 TC2
# ENT_304007 TC3
# ENT_304008 TC4
# ENT_304009 TC5
# ENT_304010 TC6
# ENT_303004 LeRaccourci
# ENT_303005 Le RaccourciVegetal
# ENT_303006 CuevaTortillaConCitron
# ENT_303007 GouffreDeLErbra
# ENT_303008 RegardResurgenceAvenir
# ENT_304011 GouffrePacifico
# ENT_304012 Pas de nom
# ENT_304013 Pas de nom
# ENT_304014 Pas de nom
# ENT_304015 PerteDuCol1
# ENT_304016 PerteduCol2
# ENT_303009 CuevaDuPlateau
# ENT_303010 IgueDuDike
# ENT_303011 Pas de nom
# ENT_304017 IgueDuMidi
# ENT_304018 IgueEnviluc
# ENT_304019 CuevaManana
# ENT_304020 TrouDuCairn
# ENT_304021 GouffreDesTroisArches
# ENT_304022 GouffreDeuxSpitsPourRien
# ENT_303012 P20
# ENT_304023 GouffreNoFutur
# ENT_304024 GouffreRetourVersLeFutur
# ENT_304025 Arc13
# ENT_304026 Arc12
# ENT_304027 Arc12
# ENT_304026 Arc12bis
# ENT_304027 Arc12bis
# ENT_304028 Arc3
# ENT_304029 Arc4
# ENT_304030 SumideroFuturo
# ENT_304031 SumideroFuturo
# ENT_304032 Gouffre N°1 Sommet 3
# ENT_304033 Pas de nom
# ENT_304034 Gouffre n°3 sommet 3
# ENT_304035 GrotteMachuPichu
# ENT_304036 GouffreUnCulDePlusAExplorer
# ENT_304037 Gouffre près du camp du Futur
# ENT_304038 Arc14
# ENT_304039 SystemaLosTubos
# ENT_304040 SumideroEscondido
# ENT_304043 SumideroEscondido
# ENT_304041 SurgenciaEstrella
# ENT_304042 CuevaEstrella
# ENT_304040 PertePerdue
# ENT_304043 PertePerdue
# ENT_304044 GouffreExploreViteFait
# ENT_304045 Puits1JeanPhi
# ENT_304046 SystemaLosTubos
# ENT_303013 Pas de nom
# ENT_304047 Arc1
# ENT_304048 Arc11
# ENT_304049 Arc111
# ENT_304050 Arc113
# ENT_304051 Arc114
# ENT_304052 Arc112
# ENT_304053 GouffreDuRobinet
# ENT_304054 CuevaDelSol
# ENT_304055 Arc19
# ENT_304056 Arc18
# ENT_304057 Arc17
# ENT_108001 OjoDeLaMadre
# ENT_108002 OmbligoDeLaMadre
# ENT_108003 Sumidero
# ENT_108004 LagrimasDeLaMadre
# ENT_108013 LagrimasDeLaMadre
# ENT_108005 Sumidero
# ENT_108006 Garganta
# ENT_108007 Sumidero
# ENT_108008 Utero de la Madre
# ENT_108009 Sumidero
# ENT_108010 Sumidero
# ENT_108011 agujero
# ENT_108012 agujero
# ENT_107002 ResurgenceXXX
# ENT_201051 Perte3
# ENT_201052 GB1
# ENT_201053 GB2
# ENT_201054 GB3
# ENT_201055 Perte2
# ENT_201056 GBTrou1
# ENT_201057 GBTrou2
# ENT_201058 GBTrou3
# ENT_201059 GB Trou 5
# ENT_201060 GouffreDuTotem
# ENT_107003 DeuxGrottes
# ENT_107004 ChattiereQuiBuffle
# ENT_107005 GouffreDeLaGrotte
# ENT_107006 MilleEtUneCascade
# ENT_107008 MilleEtUneCascade
# ENT_107007 GouffreDuCampDuNidDuCondor
# ENT_107006 EmergenceDesTuyaux
# ENT_107008 EmergenceDesTuyaux
# ENT_201061 Ayayemal
# ENT_201062 Ayayebo
# ENT_201063 GB1bis
# ENT_201064 Gouffre2
# ENT_201065 SANS NOM
# ENT_201066 SANS NOM
# ENT_201067 SANS NOM
# ENT_107009 GouffreChameau
# ENT_107010 PerteDuPointG
# ENT_107031 PuntaBlanca
# ENT_201068 GB-07-02-1
# ENT_201069 GB-07-02-2
# ENT_201070 GB-07-02-3
# ENT_201071 SANS NOM
# ENT_201072 SANS NOM
# ENT_201073 GouffreDuZiploc
# ENT_102002 PuntaEspolon
# ENT_107011 CuevaCaboVertical
# ENT_107012 CouleeBlanche
# ENT_107013 GrotteDesCanelures
# ENT_107014 DuchasDeSanPedro
# ENT_107015 EteAustral
# ENT_107016 TrouDuCarnet
# ENT_107017 N1
# ENT_107018 N1
# ENT_107017 N2
# ENT_107018 N2
# ENT_107019 GouffreCasque
# ENT_201074 CuevaHarrico
# ENT_201075 SumideroDelChorizoPlastico
# ENT_201076 SANS NOM
# ENT_201077 SANS NOM
# ENT_201078 SANS NOM
# ENT_107020 CN16-02-1
# ENT_107021 CN16-02-2
# ENT_107022 MadameCafe
# ENT_107023 CN16-02-4
# ENT_107024 CN16-02-5
# ENT_108004 GouffreLagrimas
# ENT_108013 GouffreLagrimas
# ENT_108014 GouffreDeLArche
# ENT_109003 CuevaBarachos
# ENT_109004 CuevaCaliza
# ENT_109005 EnDesespoirDeCause
# ENT_109006 P10
# ENT_109007 PetiteGrotte
# ENT_109008 GouffreHalal
# ENT_109009 Gouffralail
# ENT_109010 GouffreMaPremiere
# ENT_109011 GrandeTraversee
# ENT_109012 CuevaDeLaMerienda
# ENT_109013 Gauges
# ENT_109014 Pissotiere
# ENT_109015 TroisEntreesPlusUne
# ENT_107031 PuntaBlanca
# ENT_109016 TrouDeLaChattiere
# ENT_107026 PN01
# ENT_107027 PN02
# ENT_107028 GouffreJackpot
# ENT_107029 PerteCirque4
# ENT_109017 PetiteChinoise
# ENT_107030 CuevaCascada
# ENT_109018 ParaisoDeLasDuchas
# ENT_210001 ResurgenceFinDeSeno
# ENT_106019 LosTresRios
# ENT_106020 CuevaDelDragon
# ENT_106021 CuevaDelZorro
# ENT_213002 GrotteFinistere
# ENT_213003 PerteGlaciaire
# ENT_209053 CuevaTorseOublie
# ENT_209040 PozoAlRato
# ENT_209041 PozoDeLosCinquetenos
# ENT_209058 PerteDesSabliers
# ENT_207001 SystemeCondors
# ENT_207001 SystemeCondors
# ENT_207001 GouffrePetitCreux

# %%
CADNUM = []
for element in CADASTRE_NUMBER:
    try:
        CADNUM.append(element[1])
    except IndexError:
        print('no cad num attribué')
        CADNUM.append('NAN')
        print(element[0])
        pass
# Out:
# no cad num attribué
# PorcheDeLImpatience
# no cad num attribué
# PequinaSud
# no cad num attribué
# Perte sans nom
# no cad num attribué
# Grotte du bout du monde
# no cad num attribué
# Résurgence 3 plage de la Baleine
# no cad num attribué
# Résurgence 5 plage de la Baleine
# no cad num attribué
# ResurgenceDuChampignon
# no cad num attribué
# CuevaPirates
# no cad num attribué
# Abri1
# no cad num attribué
# Abri2
# no cad num attribué
# CuevaRien
# no cad num attribué
# Résurgence 3
# no cad num attribué
# CuevaDeLasLapas
# no cad num attribué
# GoldenIgue
# no cad num attribué
# PerteNotoCanada
# no cad num attribué
# GrotteCacahuete
# no cad num attribué
# PorcheDeLaCrevette
# no cad num attribué
# PerteJeanneDArc
# no cad num attribué
# cueva103
# no cad num attribué
# Résurgence
# no cad num attribué
# Résurgence
# no cad num attribué
# Résurgence
# no cad num attribué
# GouffreInstantané
# no cad num attribué
# GouffreDuCanyon
# no cad num attribué
# LosPiscoleros
# no cad num attribué
# Traversé du roberto
# no cad num attribué
# trou noir
# no cad num attribué
# SumideroArdilla
# no cad num attribué
# GrotteAudeline
# no cad num attribué
# Perte1
# no cad num attribué
# TrouQuiPayePasDeMine
# no cad num attribué
# GouffreSansDeconner
# no cad num attribué
# ResurgenceOubliee
# no cad num attribué
# ResurgenceDeLAvenir
# no cad num attribué
# LosGringos
# no cad num attribué
# PerteDesTetesBrulees
# no cad num attribué
# BahiaBlanca
# no cad num attribué
# TroisEntreesPlusUne
# no cad num attribué
# GrotteDesDauphins
# no cad num attribué
# QuatreEntreesPlusUne
# no cad num attribué
# ResurgenceHongo
# no cad num attribué
# MoulinReveBleu
# no cad num attribué
# PerteSaloude
# no cad num attribué
# MoulinDeGlace
# no cad num attribué
# Lac2
# no cad num attribué
# LacTicEtTac
# no cad num attribué
# CuevaEsperanza
# no cad num attribué
# FuitePrometteuse
# no cad num attribué
# TraverseeDeLaCascade
# no cad num attribué
# AbriSousGlace
# no cad num attribué
#  SaltoDelAgua
# no cad num attribué
#  MoulinAbou
# no cad num attribué
# MoulinTapisVolant
# no cad num attribué
# Traversee
# no cad num attribué
# MoulinDuChampignon
# no cad num attribué
# TraverseeDuMeandre1
# no cad num attribué
# TraverseeDuMeandre2
# no cad num attribué
# MoulinDeGlace
# no cad num attribué
# MoulinDeLaConception
# no cad num attribué
# CuevaTempanosEntree1
# no cad num attribué
# CuevaTempanosEntree2
# no cad num attribué
# CuevaTempanosEntrée3
# no cad num attribué
# HaciendasSalinas
# no cad num attribué
# ResurgenceLobos

# %%
synthese_cavites['CAD_NUM'] = CADNUM

# %%
synthese_cavites
# Out:
#      Unnamed: 0    UP                     Nom_complet  X (UTM 18 Sud)  \
# 0             0  2008  Perte du Masque et de la Plume        473667.0
# 1             1  2008            El Abrito del Viento        469367.0
# 2             2  2008               Sumidero Piquante        469510.0
# 3             3  2008             Gouffre d'Aguilucho        470302.0
# 4             4  2008           Exurgence du Picaflor        470298.0
# ..          ...   ...                             ...             ...
# 444         443  2006              Perte des Sabliers        473093.0
# 445         444  2006            Resurgence des Lobos        479668.0
# 446         445  2006             Systeme des Condors        479379.0
# 447         446  2006             Systeme des Condors        479379.0
# 448         447  2006          Gouffre du petit creux        479379.0
#
#      Y (UTM 18 Sud) Alt.  Dev. Topo Dev.estimé Prof. Topo.  ... Unnamed: 28  \
# 0         4416955.0   90     1156.0        NaN   -66   oui  ...         NaN
# 1         4421504.0  407      430.0         20  -197   oui  ...         NaN
# 2         4421914.0  191      450.0        NaN  -147   oui  ...         NaN
# 3         4421526.0   73      302.0        NaN   -97   oui  ...         NaN
# 4         4421336.0   10       40.0        NaN     5   oui  ...         NaN
# ..              ...  ...        ...        ...   ...   ...  ...         ...
# 444       4426314.0  452        NaN        NaN   NaN   NaN  ...         NaN
# 445       4427696.0    0        NaN        NaN   NaN   NaN  ...         NaN
# 446       4428572.0  141        NaN        NaN   NaN   NaN  ...         NaN
# 447       4428572.0  141        NaN        NaN   NaN   NaN  ...         NaN
# 448       4428572.0  141        NaN        NaN   NaN   NaN  ...         NaN
#
#     Unnamed: 29 Unnamed: 30 Unnamed: 31 X (UTM 18 Sud).1  Y (UTM 18 Sud).1  \
# 0           NaN         NaN         NaN          473.667          4416.955
# 1           NaN         NaN         NaN          469.367          4421.504
# 2           NaN         NaN         NaN          469.510          4421.914
# 3           NaN         NaN         NaN          470.302          4421.526
# 4           NaN         NaN         NaN          470.298          4421.336
# ..          ...         ...         ...              ...               ...
# 444         NaN         NaN         NaN              NaN               NaN
# 445         NaN         NaN         NaN              NaN               NaN
# 446         NaN         NaN         NaN              NaN               NaN
# 447         NaN         NaN         NaN              NaN               NaN
# 448         NaN         NaN         NaN              NaN               NaN
#
#      Unnamed: 34  Unnamed: 35         NomCadastre     CAD_NUM
# 0       473667.0    4416955.0   LeMasqueEtLaPlume  ENT_213001
# 1       469367.0    4421504.0     AbrigoDelViento  ENT_211001
# 2       469510.0    4421914.0    SumideroPiquante  ENT_211002
# 3       470302.0    4421526.0    GouffreAguilucho  ENT_211003
# 4       470298.0    4421336.0  ExsurgencePicaflor  ENT_211004
# ..           ...          ...                 ...         ...
# 444          NaN          NaN    PerteDesSabliers  ENT_209058
# 445          NaN          NaN     ResurgenceLobos         NAN
# 446          NaN          NaN      SystemeCondors  ENT_207001
# 447          NaN          NaN      SystemeCondors  ENT_207001
# 448          NaN          NaN   GouffrePetitCreux  ENT_207001
#
# [449 rows x 39 columns]

# %%
print(synthese_cavites.columns)
# Out:
# Index(['Unnamed: 0', 'UP', 'Nom_complet', 'X (UTM 18 Sud)', 'Y (UTM 18 Sud)',
#        'Alt.', 'Dev. Topo', 'Dev.estimé', 'Prof.', 'Topo.', 'Termine?',
#        'Secteur', 'Commentaire', 'Explorateurs', 'ARCHEO', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'X (UTM 18 Sud).1', 'Y (UTM 18 Sud).1', 'Unnamed: 34',
#        'Unnamed: 35', 'NomCadastre', 'CAD_NUM'],
#       dtype='object')

# %%
columns = ['CAD_NUM','NomCadastre','Nom_complet','X (UTM 18 Sud)', 'Y (UTM 18 Sud)','Alt.','Dev. Topo','Termine?', 'Dev.estimé',"Prof.",'UP','Commentaire','Explorateurs']
NOUVELLE_SYNTHESE = synthese_cavites[columns]

# %%
NOUVELLE_SYNTHESE.sort_values(by='CAD_NUM').to_csv('../data/cadastre/UP_MDD_DDA_Temp_synthese_Cavites_NumCad.csv')

# %%
MAUVAIS_NOM = []

for dirpath, dirnames, filenames in os.walk('../data'):
    # check along each directory.
    for name in dirnames:
        #print(name)
        # find all cave folders, each has a three digit cadastre sector identifier in path
        if not re.match('\d{3}', name):
            if re.match('.*\d{3}',dirpath) and (name !='outputs'):
                print('yay!', name,dirpath)
                try:
                    print(name)
                    #print(NOUVELLE_SYNTHESE[NOUVELLE_SYNTHESE['NomCadastre']==name])
                except KeyError:
                    pass
                    print(name)
                    print("cette grotte n'est pas dans le xls")
                    MAUVAIS_NOM.append(name)
# Out:
# yay! MD-BDG05 ../data/211
# MD-BDG05
# yay! GouffreAguilucho ../data/211
# GouffreAguilucho
# yay! PorcheDeLaMadre2 ../data/211
# PorcheDeLaMadre2
# yay! AbrigoDelViento ../data/211
# AbrigoDelViento
# yay! MD-BDGS04 ../data/211
# MD-BDGS04
# yay! MD-BDGS03 ../data/211
# MD-BDGS03
# yay! GrottePetiteSoeur ../data/211
# GrottePetiteSoeur
# yay! PuitsOctopus ../data/211
# PuitsOctopus
# yay! MD-BDGS02 ../data/211
# MD-BDGS02
# yay! IgueDeDob ../data/211
# IgueDeDob
# yay! GouffreDeLArche ../data/211
# GouffreDeLArche
# yay! GrandAvenTriple ../data/211
# GrandAvenTriple
# yay! GrotteDuNomade ../data/211
# GrotteDuNomade
# yay! GrotteGrandeSoeur ../data/211
# GrotteGrandeSoeur
# yay! GrotteMarion ../data/211
# GrotteMarion
# yay! AvenDeLaTraverse ../data/211
# AvenDeLaTraverse
# yay! GrotteDeLaConduite ../data/211
# GrotteDeLaConduite
# yay! GrotteFilostik ../data/211
# GrotteFilostik
# yay! GouffreDesMousquetaires ../data/211
# GouffreDesMousquetaires
# yay! Gouffre36 ../data/211
# Gouffre36
# yay! PorcheDeLImpatience ../data/211
# PorcheDeLImpatience
# yay! MeandreDesSables ../data/211
# MeandreDesSables
# yay! MD-BDGS01 ../data/211
# MD-BDGS01
# yay! PerteDesLobos ../data/211
# PerteDesLobos
# yay! Perte1Lobos ../data/211
# Perte1Lobos
# yay! ExsurgencePicaflor ../data/211
# ExsurgencePicaflor
# yay! LaGrotte ../data/211
# LaGrotte
# yay! GouffreCumpleAnos ../data/211
# GouffreCumpleAnos
# yay! ElCuloDeLaMadre ../data/211
# ElCuloDeLaMadre
# yay! CuevaDelAgua ../data/211
# CuevaDelAgua
# yay! LobosMatos ../data/211
# LobosMatos
# yay! SumideroPiquante ../data/211
# SumideroPiquante
# yay! GrotteDeLobosSecos ../data/211
# GrotteDeLobosSecos
# yay! SimaDelCol ../data/211
# SimaDelCol
# yay! ResurgenceFinDeSeno ../data/210
# ResurgenceFinDeSeno
# yay! GrotteFaussePucelle ../data/204
# GrotteFaussePucelle
# yay! GrotteCacahuete ../data/204
# GrotteCacahuete
# yay! GrotteDuRapace ../data/204
# GrotteDuRapace
# yay! GouffreAlouette ../data/204
# GouffreAlouette
# yay! GrotteDeLOursin ../data/204
# GrotteDeLOursin
# yay! EvequeCauchon ../data/204
# EvequeCauchon
# yay! GouffreGazelle ../data/204
# GouffreGazelle
# yay! TrouDesCanelures ../data/204
# TrouDesCanelures
# yay! AbriDuGazon ../data/203
# AbriDuGazon
# yay! PuitsDuBourdon ../data/203
# PuitsDuBourdon
# yay! GrotteDuNord ../data/203
# GrotteDuNord
# yay! PerteDuCoypo ../data/203
# PerteDuCoypo
# yay! GrosTrou ../data/203
# GrosTrou
# yay! GouffreFelin ../data/203
# GouffreFelin
# yay! PerteFaille ../data/205
# PerteFaille
# yay! JamesBonde ../data/205
# JamesBonde
# yay! GrotteSueno ../data/205
# GrotteSueno
# yay! IgueDuPlouc ../data/205
# IgueDuPlouc
# yay! AbriDuCerfeuil ../data/205
# AbriDuCerfeuil
# yay! CuevaArdilla ../data/205
# CuevaArdilla
# yay! PerteDuJump ../data/205
# PerteDuJump
# yay! PerteInattendue ../data/205
# PerteInattendue
# yay! SumideroJuanito ../data/205
# SumideroJuanito
# yay! PerteAmbree ../data/205
# PerteAmbree
# yay! Sou33 ../data/205
# Sou33
# yay! FailleDuCoinceur ../data/205
# FailleDuCoinceur
# yay! CuevaLaBas ../data/205
# CuevaLaBas
# yay! MD-SOU02 ../data/205
# MD-SOU02
# yay! GoldenIgue ../data/205
# GoldenIgue
# yay! GrotteDuSud ../data/205
# GrotteDuSud
# yay! CuevaDeLaFinDeMatinas ../data/205
# CuevaDeLaFinDeMatinas
# yay! CuevaDeLaMadre ../data/205
# CuevaDeLaMadre
# yay! PerteDesDents ../data/205
# PerteDesDents
# yay! PerteDesQuatreChampignons ../data/205
# PerteDesQuatreChampignons
# yay! PozoEnBosque ../data/205
# PozoEnBosque
# yay! Sou31 ../data/205
# Sou31
# yay! PorcheBaleine ../data/205
# PorcheBaleine
# yay! Sou30 ../data/205
# Sou30
# yay! AbriGite ../data/205
# AbriGite
# yay! GrotteAudeline ../data/205
# GrotteAudeline
# yay! AbriCotier ../data/205
# AbriCotier
# yay! MD-SOU01 ../data/205
# MD-SOU01
# yay! CuevaTortillaConCitron ../data/303
# CuevaTortillaConCitron
# yay! PerteDesPortesDAbraham ../data/303
# PerteDesPortesDAbraham
# yay! IgueDuDike ../data/303
# IgueDuDike
# yay! CuevaDuPlateau ../data/303
# CuevaDuPlateau
# yay! GouffreDeLErbra ../data/303
# GouffreDeLErbra
# yay! CuevaNutria ../data/303
# CuevaNutria
# yay! CuevaManana ../data/304
# CuevaManana
# yay! Arc18 ../data/304
# Arc18
# yay! CuevaDelSol ../data/304
# CuevaDelSol
# yay! TC1 ../data/304
# TC1
# yay! TC6 ../data/304
# TC6
# yay! Arc17 ../data/304
# Arc17
# yay! Arc19 ../data/304
# Arc19
# yay! OjoDelDiablo ../data/304
# OjoDelDiablo
# yay! Arc3 ../data/304
# Arc3
# yay! Arc4 ../data/304
# Arc4
# yay! GouffreDeuxSpitsPourRien ../data/304
# GouffreDeuxSpitsPourRien
# yay! Arc12bis ../data/304
# Arc12bis
# yay! Arc113 ../data/304
# Arc113
# yay! GouffreDuRobinet ../data/304
# GouffreDuRobinet
# yay! Arc114 ../data/304
# Arc114
# yay! PerteDuCol1 ../data/304
# PerteDuCol1
# yay! PertePerdue ../data/304
# PertePerdue
# yay! CuevaEstrella ../data/304
# CuevaEstrella
# yay! GrotteMachuPichu ../data/304
# GrotteMachuPichu
# yay! GouffreNoFutur ../data/304
# GouffreNoFutur
# yay! SystemaLosTubos ../data/304
# SystemaLosTubos
# yay! TC3 ../data/304
# TC3
# yay! TC4 ../data/304
# TC4
# yay! Arc13 ../data/304
# Arc13
# yay! Arc14 ../data/304
# Arc14
# yay! SumideroFuturo ../data/304
# SumideroFuturo
# yay! TC5 ../data/304
# TC5
# yay! PerteDeLaSucriereInferieure ../data/304
# PerteDeLaSucriereInferieure
# yay! TC2 ../data/304
# TC2
# yay! GouffreDesTroisArches ../data/304
# GouffreDesTroisArches
# yay! PerteCol1 ../data/304
# PerteCol1
# yay! SumideroEscondido ../data/304
# SumideroEscondido
# yay! GouffreRetourVersLeFutur ../data/304
# GouffreRetourVersLeFutur
# yay! GouffrePacifico ../data/304
# GouffrePacifico
# yay! Arc111 ../data/304
# Arc111
# yay! IgueEnviluc ../data/304
# IgueEnviluc
# yay! IgueDuMidi ../data/304
# IgueDuMidi
# yay! PerteduCol2 ../data/304
# PerteduCol2
# yay! SurgenciaEstrella ../data/304
# SurgenciaEstrella
# yay! Puits1JeanPhi ../data/304
# Puits1JeanPhi
# yay! TrouDuCairn ../data/304
# TrouDuCairn
# yay! ResurgenceDeLAvenir ../data/304
# ResurgenceDeLAvenir
# yay! QuatreEntreesPlusUne ../data/109
# QuatreEntreesPlusUne
# yay! P10 ../data/109
# P10
# yay! CuevaCaliza ../data/109
# CuevaCaliza
# yay! EnDesespoirDeCause ../data/109
# EnDesespoirDeCause
# yay! CuevaDeLaMerienda ../data/109
# CuevaDeLaMerienda
# yay! GouffreHalal ../data/109
# GouffreHalal
# yay! ParaisoDeLasDuchas ../data/109
# ParaisoDeLasDuchas
# yay! TroisEntreesPlusUne ../data/109
# TroisEntreesPlusUne
# yay! CuevaBarachos ../data/109
# CuevaBarachos
# yay! PetiteGrotte ../data/109
# PetiteGrotte
# yay! PetiteChinoise ../data/109
# PetiteChinoise
# yay! TrouDeLaChattiere ../data/109
# TrouDeLaChattiere
# yay! Gouffralail ../data/109
# Gouffralail
# yay! TroisPorches ../data/109
# TroisPorches
# yay! Pissotiere ../data/109
# Pissotiere
# yay! GrandeTraversee ../data/109
# GrandeTraversee
# yay! Gauges ../data/109
# Gauges
# yay! GouffreDuCampDuNidDuCondor ../data/107
# GouffreDuCampDuNidDuCondor
# yay! ResurgenceHongo ../data/107
# ResurgenceHongo
# yay! GrotteDesCanelures ../data/107
# GrotteDesCanelures
# yay! GouffreJackpot ../data/107
# GouffreJackpot
# yay! MadameCafe ../data/107
# MadameCafe
# yay! CN16-02-4 ../data/107
# CN16-02-4
# yay! CuevaCaboVertical ../data/107
# CuevaCaboVertical
# yay! DuchasDeSanPedro ../data/107
# DuchasDeSanPedro
# yay! CN16-02-2 ../data/107
# CN16-02-2
# yay! CuevaDesLosPescadores ../data/107
# CuevaDesLosPescadores
# yay! CN16-02-5 ../data/107
# CN16-02-5
# yay! MilleEtUneCascade ../data/107
# MilleEtUneCascade
# yay! PN02 ../data/107
# PN02
# yay! DeuxGrottes ../data/107
# DeuxGrottes
# yay! CuevaCascada ../data/107
# CuevaCascada
# yay! PerteDuPointG ../data/107
# PerteDuPointG
# yay! CouleeBlanche ../data/107
# CouleeBlanche
# yay! GouffreChameau ../data/107
# GouffreChameau
# yay! PuntaBlanca ../data/107
# PuntaBlanca
# yay! BahiaBlanca ../data/107
# BahiaBlanca
# yay! ChattiereQuiBuffle ../data/107
# ChattiereQuiBuffle
# yay! N2 ../data/107
# N2
# yay! EmergenceDesTuyaux ../data/107
# EmergenceDesTuyaux
# yay! PerteCirque4 ../data/107
# PerteCirque4
# yay! GouffreCasque ../data/107
# GouffreCasque
# yay! PN01 ../data/107
# PN01
# yay! CN16-02-1 ../data/107
# CN16-02-1
# yay! LosTresRios ../data/106
# LosTresRios
# yay! HaciendasSalinas ../data/106
# HaciendasSalinas
# yay! CuevaPirates ../data/106
# CuevaPirates
# yay! CuevaDelDragon ../data/106
# CuevaDelDragon
# yay! ResurgenceNoTime ../data/106
# ResurgenceNoTime
# yay! CuevaNoTime ../data/106
# CuevaNoTime
# yay! CuevaDelZorro ../data/106
# CuevaDelZorro
# yay! OjoDeLaMadre ../data/108
# OjoDeLaMadre
# yay! GouffreDeLArche ../data/108
# GouffreDeLArche
# yay! GouffreLagrimas ../data/108
# GouffreLagrimas
# yay! OmbligoDeLaMadre ../data/108
# OmbligoDeLaMadre
# yay! LagrimasDeLaMadre ../data/108
# LagrimasDeLaMadre
# yay! GrotteDeTarlton ../data/212
# GrotteDeTarlton
# yay! TAR04 ../data/212
# TAR04
# yay! TAR03 ../data/212
# TAR03
# yay! TAR02 ../data/212
# TAR02
# yay! TAR05 ../data/212
# TAR05
# yay! TAR01 ../data/212
# TAR01
# yay! GrotteFinistere ../data/213
# GrotteFinistere
# yay! LeMasqueEtLaPlume ../data/213
# LeMasqueEtLaPlume
# yay! PerteGlaciaire ../data/213
# PerteGlaciaire
# yay! AvenKinka4 ../data/209
# AvenKinka4
# yay! AvenKinka3 ../data/209
# AvenKinka3
# yay! CuevaTorseOublie ../data/209
# CuevaTorseOublie
# yay! AvenKinka2 ../data/209
# AvenKinka2
# yay! PozoAlRato ../data/209
# PozoAlRato
# yay! GouffreDuKit ../data/209
# GouffreDuKit
# yay! DolineCalafate ../data/209
# DolineCalafate
# yay! GouffreDeLaGachette ../data/209
# GouffreDeLaGachette
# yay! ResurgenceDeLaPlage ../data/209
# ResurgenceDeLaPlage
# yay! CuevaGringa ../data/209
# CuevaGringa
# yay! LosGringos ../data/209
# LosGringos
# yay! PozoDeLosCinquetenos ../data/209
# PozoDeLosCinquetenos
# yay! PerteDesSabliers ../data/209
# PerteDesSabliers
# yay! GrotteEvier ../data/209
# GrotteEvier
# yay! GrotteDuPleinCintre ../data/209
# GrotteDuPleinCintre
# yay! AvenKinka1 ../data/209
# AvenKinka1
# yay! GouffreCumpleAnos ../data/209
# GouffreCumpleAnos
# yay! GrandeDolinePerte ../data/209
# GrandeDolinePerte
# yay! GrandAvenPerte ../data/209
# GrandAvenPerte
# yay! BobLEponge ../data/209
# BobLEponge
# yay! LaMarmotte ../data/209
# LaMarmotte
# yay! GouffreDeLaDetente ../data/209
# GouffreDeLaDetente
# yay! EmergenceBarillet ../data/209
# EmergenceBarillet
# yay! TROUA ../data/209
# TROUA
# yay! ResurgenceLobos ../data/207
# ResurgenceLobos
# yay! SystemeCondors ../data/207
# SystemeCondors
# yay! GouffrePetitCreux ../data/206
# GouffrePetitCreux
# yay! PerteDuMoral ../data/206
# PerteDuMoral
# yay! CuevaAyayema ../data/206
# CuevaAyayema
# yay! PozoDelContacto ../data/206
# PozoDelContacto
# yay! PerteDuTemps ../data/206
# PerteDuTemps
# yay! Passoire ../data/206
# Passoire
# yay! CuevaComete ../data/206
# CuevaComete
# yay! PerteDeLaRiviere ../data/206
# PerteDeLaRiviere
# yay! GrotteDuDyke ../data/206
# GrotteDuDyke
# yay! P85Camp400 ../data/206
# P85Camp400
# yay! CuevaDuTelephone ../data/201
# CuevaDuTelephone
# yay! GouffreDuTotem ../data/201
# GouffreDuTotem
# yay! LaRabasse3 ../data/201
# LaRabasse3
# yay! Ayayemal ../data/201
# Ayayemal
# yay! GB01 ../data/201
# GB01
# yay! GB1 ../data/201
# GB1
# yay! GB08 ../data/201
# GB08
# yay! LaRabasse2 ../data/201
# LaRabasse2
# yay! C4SansNom10 ../data/201
# C4SansNom10
# yay! TrouDuMarteau ../data/201
# TrouDuMarteau
# yay! GB-07-02-2 ../data/201
# GB-07-02-2
# yay! PorcheDuSonnar ../data/201
# PorcheDuSonnar
# yay! GB-07-02-3 ../data/201
# GB-07-02-3
# yay! Porche2 ../data/201
# Porche2
# yay! Cueva12 ../data/201
# Cueva12
# yay! C4T2 ../data/201
# C4T2
# yay! Ayayebo ../data/201
# Ayayebo
# yay! GouffreDuColibri ../data/201
# GouffreDuColibri
# yay! C4Nfissure0 ../data/201
# C4Nfissure0
# yay! C4T3 ../data/201
# C4T3
# yay! Cueva13 ../data/201
# Cueva13
# yay! GBTrou1 ../data/201
# GBTrou1
# yay! C4SansNom2 ../data/201
# C4SansNom2
# yay! CuevaChampignon ../data/201
# CuevaChampignon
# yay! C4SansNom5 ../data/201
# C4SansNom5
# yay! CuevaDeLaCasquette ../data/201
# CuevaDeLaCasquette
# yay! Resurgence1 ../data/201
# Resurgence1
# yay! C4Cueva6 ../data/201
# C4Cueva6
# yay! C4SansNom4 ../data/201
# C4SansNom4
# yay! Cueva4 ../data/201
# Cueva4
# yay! C4SansNom3 ../data/201
# C4SansNom3
# yay! GB2 ../data/201
# GB2
# yay! Perte2 ../data/201
# Perte2
# yay! GB3 ../data/201
# GB3
# yay! LaRabasse1 ../data/201
# LaRabasse1
# yay! Perte3 ../data/201
# Perte3
# yay! C5Cueva2 ../data/201
# C5Cueva2
# yay! Haricot ../data/201
# Haricot
# yay! GB-07-02-1 ../data/201
# GB-07-02-1
# yay! C5Cueva3 ../data/201
# C5Cueva3
# yay! Porche1 ../data/201
# Porche1
# yay! Champignon ../data/201
# Champignon
# yay! GouffreColibri ../data/201
# GouffreColibri
# yay! Cueva11 ../data/201
# Cueva11
# yay! GB1bis ../data/201
# GB1bis
# yay! C4T1 ../data/201
# C4T1
# yay! SumideroDelChorizoPlastico ../data/201
# SumideroDelChorizoPlastico
# yay! Ziploc ../data/201
# Ziploc
# yay! PorcheOsDeBaleine ../data/201
# PorcheOsDeBaleine
# yay! TrouDeLaPlaquette ../data/201
# TrouDeLaPlaquette
# yay! Cueva1 ../data/201
# Cueva1
# yay! C4SansNom6 ../data/201
# C4SansNom6
# yay! C4SansNom1 ../data/201
# C4SansNom1
# yay! C4SansNom8 ../data/201
# C4SansNom8
# yay! Cueva8 ../data/201
# Cueva8
# yay! GouffreDuZiploc ../data/201
# GouffreDuZiploc
# yay! GBTrou2 ../data/201
# GBTrou2
# yay! C4SansNom9 ../data/201
# C4SansNom9
# yay! Cueva7 ../data/201
# Cueva7
# yay! C4SansNom7 ../data/201
# C4SansNom7
# yay! GBTrou3 ../data/201
# GBTrou3
# yay! PorcheSonna ../data/201
# PorcheSonna
# yay! GB01 ../data/201/C4SansNom4
# GB01
# yay! Cueva10H10 ../data/208
# Cueva10H10
# yay! Grotte20PlageDeLaBaleine ../data/208
# Grotte20PlageDeLaBaleine

# %%
IN_FOLDER = []
for NAME in NOUVELLE_SYNTHESE['NomCadastre']:
    
    COND = False
    for dirpath, dirnames, filenames in os.walk('../data'):
    # check along each directory.
        for name in dirnames:
            if NAME in name:
                print(NAME,name,dirpath)
                COND = True
    IN_FOLDER.append((NAME,COND))
# Out:
# LeMasqueEtLaPlume LeMasqueEtLaPlume ../data/213
# AbrigoDelViento AbrigoDelViento ../data/211
# SumideroPiquante SumideroPiquante ../data/211
# GouffreAguilucho GouffreAguilucho ../data/211
# ExsurgencePicaflor ExsurgencePicaflor ../data/211
# PorcheDeLImpatience PorcheDeLImpatience ../data/211
# SimaDelCol SimaDelCol ../data/211
# MD-BDGS01 MD-BDGS01 ../data/211
# MD-BDGS02 MD-BDGS02 ../data/211
# MD-BDGS03 MD-BDGS03 ../data/211
# MD-BDGS04 MD-BDGS04 ../data/211
# MD-BDG05 MD-BDG05 ../data/211
# PleinCintre GrotteDuPleinCintre ../data/209
# EmergenceBarillet EmergenceBarillet ../data/209
# GouffreDeLaGachette GouffreDeLaGachette ../data/209
# ResurgenceDeLaPlage ResurgenceDeLaPlage ../data/209
# GrotteEvier GrotteEvier ../data/209
# BobLEponge BobLEponge ../data/209
# CuevaGringa CuevaGringa ../data/209
# Cueva10H10 Cueva10H10 ../data/208
# AbriCotier AbriCotier ../data/205
# Grotte20PlageDeLaBaleine Grotte20PlageDeLaBaleine ../data/208
# AbriDuCerfeuil AbriDuCerfeuil ../data/205
# CuevaAyayema CuevaAyayema ../data/206
# GrotteDuDyke GrotteDuDyke ../data/206
# CuevaLaBas CuevaLaBas ../data/205
# PerteDesDents PerteDesDents ../data/205
# SumideroJuanito SumideroJuanito ../data/205
# CuevaArdilla CuevaArdilla ../data/205
# PozoEnBosque PozoEnBosque ../data/205
# MD-SOU01 MD-SOU01 ../data/205
# MD-SOU02 MD-SOU02 ../data/205
# DolineCalafate DolineCalafate ../data/209
# CuevaPirates CuevaPirates ../data/106
# CuevaNoTime CuevaNoTime ../data/106
# ResurgenceNoTime ResurgenceNoTime ../data/106
# CuevaNutria CuevaNutria ../data/303
# Porche PorcheDeLaMadre2 ../data/211
# Porche PorcheDeLImpatience ../data/211
# Porche PorcheBaleine ../data/205
# Porche TroisPorches ../data/109
# Porche PorcheDuSonnar ../data/201
# Porche Porche2 ../data/201
# Porche Porche1 ../data/201
# Porche PorcheOsDeBaleine ../data/201
# Porche PorcheSonna ../data/201
# Grotte GrottePetiteSoeur ../data/211
# Grotte GrotteDuNomade ../data/211
# Grotte GrotteGrandeSoeur ../data/211
# Grotte GrotteMarion ../data/211
# Grotte GrotteDeLaConduite ../data/211
# Grotte GrotteFilostik ../data/211
# Grotte LaGrotte ../data/211
# Grotte GrotteDeLobosSecos ../data/211
# Grotte GrotteFaussePucelle ../data/204
# Grotte GrotteCacahuete ../data/204
# Grotte GrotteDuRapace ../data/204
# Grotte GrotteDeLOursin ../data/204
# Grotte GrotteDuNord ../data/203
# Grotte GrotteSueno ../data/205
# Grotte GrotteDuSud ../data/205
# Grotte GrotteAudeline ../data/205
# Grotte GrotteMachuPichu ../data/304
# Grotte PetiteGrotte ../data/109
# Grotte GrotteDesCanelures ../data/107
# Grotte DeuxGrottes ../data/107
# Grotte GrottePayePasDeMine ../data/ovni
# Grotte GrotteDeTarlton ../data/212
# Grotte GrotteFinistere ../data/213
# Grotte GrotteEvier ../data/209
# Grotte GrotteDuPleinCintre ../data/209
# Grotte GrotteDuDyke ../data/206
# Grotte Grotte20PlageDeLaBaleine ../data/208
# Porche PorcheDeLaMadre2 ../data/211
# Porche PorcheDeLImpatience ../data/211
# Porche PorcheBaleine ../data/205
# Porche TroisPorches ../data/109
# Porche PorcheDuSonnar ../data/201
# Porche Porche2 ../data/201
# Porche Porche1 ../data/201
# Porche PorcheOsDeBaleine ../data/201
# Porche PorcheSonna ../data/201
# TroisPorches TroisPorches ../data/109
# TroisPorches TroisPorches ../data/109
# CuevaDesLosPescadores CuevaDesLosPescadores ../data/107
# GrotteDeTarlton GrotteDeTarlton ../data/212
# TAR01 TAR01 ../data/212
# TAR02 TAR02 ../data/212
# TAR03 TAR03 ../data/212
# TAR04 TAR04 ../data/212
# TAR05 TAR05 ../data/212
# PerteInattendue PerteInattendue ../data/205
# PerteAmbree PerteAmbree ../data/205
# PerteFaille PerteFaille ../data/205
# PerteDesQuatreChampignons PerteDesQuatreChampignons ../data/205
# GoldenIgue GoldenIgue ../data/205
# GouffreGazelle GouffreGazelle ../data/204
# EvequeCauchon EvequeCauchon ../data/204
# JamesBonde JamesBonde ../data/205
# GrotteFaussePucelle GrotteFaussePucelle ../data/204
# GrotteCacahuete GrotteCacahuete ../data/204
# PerteDuJump PerteDuJump ../data/205
# GrotteGrandeSoeur GrotteGrandeSoeur ../data/211
# FailleDuCoinceur FailleDuCoinceur ../data/205
# IgueDuPlouc IgueDuPlouc ../data/205
# CuevaDeLaFinDeMatinas CuevaDeLaFinDeMatinas ../data/205
# GouffreAlouette GouffreAlouette ../data/204
# PerteDuCoypo PerteDuCoypo ../data/203
# GouffreFelin GouffreFelin ../data/203
# PuitsDuBourdon PuitsDuBourdon ../data/203
# GrosTrou GrosTrou ../data/203
# TrouDesCanelures TrouDesCanelures ../data/204
# Perte1 Perte1Lobos ../data/211
# Perte2 Perte2 ../data/201
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# LaRabasse3 LaRabasse3 ../data/201
# LaRabasse1 LaRabasse1 ../data/201
# Cueva3 C5Cueva3 ../data/201
# Cueva7 Cueva7 ../data/201
# Cueva1 Cueva12 ../data/201
# Cueva1 Cueva13 ../data/201
# Cueva1 Cueva11 ../data/201
# Cueva1 Cueva1 ../data/201
# Cueva1 Cueva10H10 ../data/208
# Cueva11 Cueva11 ../data/201
# CuevaDuTelephone CuevaDuTelephone ../data/201
# Cueva8 Cueva8 ../data/201
# TrouDuMarteau TrouDuMarteau ../data/201
# LaRabasse2 LaRabasse2 ../data/201
# Cueva10 Cueva10H10 ../data/208
# Cueva2 C5Cueva2 ../data/201
# Cueva12 Cueva12 ../data/201
# Cueva13 Cueva13 ../data/201
# PorcheBaleine PorcheBaleine ../data/205
# Porche1 Porche1 ../data/201
# C4T2 C4T2 ../data/201
# C4T3 C4T3 ../data/201
# Cueva4 Cueva4 ../data/201
# C4T1 C4T1 ../data/201
# C3 TC3 ../data/304
# C4Cueva6 C4Cueva6 ../data/201
# C4SansNom10 C4SansNom10 ../data/201
# C4SansNom9 C4SansNom9 ../data/201
# C4Nfissure0 C4Nfissure0 ../data/201
# C4SansNom8 C4SansNom8 ../data/201
# C4SansNom7 C4SansNom7 ../data/201
# C4SansNom6 C4SansNom6 ../data/201
# C5Cueva2 C5Cueva2 ../data/201
# C4SansNom1 C4SansNom10 ../data/201
# C4SansNom1 C4SansNom1 ../data/201
# C4SansNom4 C4SansNom4 ../data/201
# C5Cueva3 C5Cueva3 ../data/201
# C4SansNom3 C4SansNom3 ../data/201
# CuevaDeLaCasquette CuevaDeLaCasquette ../data/201
# Champignon PerteDesQuatreChampignons ../data/205
# Champignon CuevaChampignon ../data/201
# Champignon Champignon ../data/201
# GouffreDuColibri GouffreDuColibri ../data/201
# TrouDeLaPlaquette TrouDeLaPlaquette ../data/201
# PorcheDuSonnar PorcheDuSonnar ../data/201
# AbriDuGazon AbriDuGazon ../data/203
# AbriGite AbriGite ../data/205
# GrotteDuRapace GrotteDuRapace ../data/204
# GrotteDuSud GrotteDuSud ../data/205
# GrotteDeLOursin GrotteDeLOursin ../data/204
# CuevaDeLaMadre CuevaDeLaMadre ../data/205
# Porche PorcheDeLaMadre2 ../data/211
# Porche PorcheDeLImpatience ../data/211
# Porche PorcheBaleine ../data/205
# Porche TroisPorches ../data/109
# Porche PorcheDuSonnar ../data/201
# Porche Porche2 ../data/201
# Porche Porche1 ../data/201
# Porche PorcheOsDeBaleine ../data/201
# Porche PorcheSonna ../data/201
# GrotteDuNord GrotteDuNord ../data/203
# GouffreDeLaDetente GouffreDeLaDetente ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Gouffre36 Gouffre36 ../data/211
# GouffreDesMousquetaires GouffreDesMousquetaires ../data/211
# GouffreDeLArche GouffreDeLArche ../data/211
# GouffreDeLArche GouffreDeLArche ../data/108
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# GrotteDeLobosSecos GrotteDeLobosSecos ../data/211
# GrotteMarion GrotteMarion ../data/211
# MeandreDesSables MeandreDesSables ../data/211
# GrotteDeLaConduite GrotteDeLaConduite ../data/211
# CuevaDelAgua CuevaDelAgua ../data/211
# AvenDeLaTraverse AvenDeLaTraverse ../data/211
# GrotteDuNomade GrotteDuNomade ../data/211
# GrotteFilostik GrotteFilostik ../data/211
# PorcheDeLaMadre2 PorcheDeLaMadre2 ../data/211
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# GrandAvenTriple GrandAvenTriple ../data/211
# Cueva1 Cueva12 ../data/201
# Cueva1 Cueva13 ../data/201
# Cueva1 Cueva11 ../data/201
# Cueva1 Cueva1 ../data/201
# Cueva1 Cueva10H10 ../data/208
# Porche PorcheDeLaMadre2 ../data/211
# Porche PorcheDeLImpatience ../data/211
# Porche PorcheBaleine ../data/205
# Porche TroisPorches ../data/109
# Porche PorcheDuSonnar ../data/201
# Porche Porche2 ../data/201
# Porche Porche1 ../data/201
# Porche PorcheOsDeBaleine ../data/201
# Porche PorcheSonna ../data/201
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# LobosMatos LobosMatos ../data/211
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Cueva6 C4Cueva6 ../data/201
# Perte1Lobos Perte1Lobos ../data/211
# GrotteAudeline GrotteAudeline ../data/205
# PerteDesLobos PerteDesLobos ../data/211
# PerteDesLobos PerteDesLobos ../data/ovni
# ElCuloDeLaMadre ElCuloDeLaMadre ../data/211
# LaGrotte LaGrotte ../data/211
# IgueDeDob IgueDeDob ../data/211
# GrottePetiteSoeur GrottePetiteSoeur ../data/211
# PuitsOctopus PuitsOctopus ../data/211
# GouffreDuKit GouffreDuKit ../data/209
# GouffreCumpleAnos GouffreCumpleAnos ../data/211
# GouffreCumpleAnos GouffreCumpleAnos ../data/209
# LaMarmotte LaMarmotte ../data/209
# AvenKinka4 AvenKinka4 ../data/209
# Perte3 Perte3 ../data/201
# AvenKinka3 AvenKinka3 ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# AvenKinka2 AvenKinka2 ../data/209
# AvenKinka1 AvenKinka1 ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# GrandAvenPerte GrandAvenPerte ../data/209
# TROUA TROUA ../data/209
# GrandeDolinePerte GrandeDolinePerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# Sou33 Sou33 ../data/205
# Sou30 Sou30 ../data/205
# Sou31 Sou31 ../data/205
# Porche PorcheDeLaMadre2 ../data/211
# Porche PorcheDeLImpatience ../data/211
# Porche PorcheBaleine ../data/205
# Porche TroisPorches ../data/109
# Porche PorcheDuSonnar ../data/201
# Porche Porche2 ../data/201
# Porche Porche1 ../data/201
# Porche PorcheOsDeBaleine ../data/201
# Porche PorcheSonna ../data/201
# GrotteAudeline GrotteAudeline ../data/205
# Aven GrandAvenTriple ../data/211
# Aven AvenDeLaTraverse ../data/211
# Aven ResurgenceDeLAvenir ../data/304
# Aven AvenKinka4 ../data/209
# Aven AvenKinka3 ../data/209
# Aven AvenKinka2 ../data/209
# Aven AvenKinka1 ../data/209
# Aven GrandAvenPerte ../data/209
# GrotteSueno GrotteSueno ../data/205
# Perte1 Perte1Lobos ../data/211
# PerteDeLaSucriere PerteDeLaSucriereInferieure ../data/304
# OjoDelDiablo OjoDelDiablo ../data/304
# PerteDeLaSucriereInferieure PerteDeLaSucriereInferieure ../data/304
# PerteCol1 PerteCol1 ../data/304
# PerteDesPortesDAbraham PerteDesPortesDAbraham ../data/303
# CuevaNutria CuevaNutria ../data/303
# TC1 TC1 ../data/304
# TC2 TC2 ../data/304
# TC3 TC3 ../data/304
# TC4 TC4 ../data/304
# TC5 TC5 ../data/304
# TC6 TC6 ../data/304
# CuevaTortillaConCitron CuevaTortillaConCitron ../data/303
# GouffreDeLErbra GouffreDeLErbra ../data/303
# GouffrePacifico GouffrePacifico ../data/304
# PerteDuCol1 PerteDuCol1 ../data/304
# PerteduCol2 PerteduCol2 ../data/304
# CuevaDuPlateau CuevaDuPlateau ../data/303
# IgueDuDike IgueDuDike ../data/303
# IgueDuMidi IgueDuMidi ../data/304
# IgueEnviluc IgueEnviluc ../data/304
# CuevaManana CuevaManana ../data/304
# TrouDuCairn TrouDuCairn ../data/304
# GouffreDesTroisArches GouffreDesTroisArches ../data/304
# GouffreDeuxSpitsPourRien GouffreDeuxSpitsPourRien ../data/304
# GouffreNoFutur GouffreNoFutur ../data/304
# GouffreRetourVersLeFutur GouffreRetourVersLeFutur ../data/304
# Arc13 Arc13 ../data/304
# Arc12 Arc12bis ../data/304
# Arc12bis Arc12bis ../data/304
# Arc3 Arc3 ../data/304
# Arc4 Arc4 ../data/304
# SumideroFuturo SumideroFuturo ../data/304
# SumideroFuturo SumideroFuturo ../data/304
# GrotteMachuPichu GrotteMachuPichu ../data/304
# Arc14 Arc14 ../data/304
# SystemaLosTubos SystemaLosTubos ../data/304
# SumideroEscondido SumideroEscondido ../data/304
# SurgenciaEstrella SurgenciaEstrella ../data/304
# CuevaEstrella CuevaEstrella ../data/304
# PertePerdue PertePerdue ../data/304
# Puits1JeanPhi Puits1JeanPhi ../data/304
# SystemaLosTubos SystemaLosTubos ../data/304
# Arc1 Arc18 ../data/304
# Arc1 Arc17 ../data/304
# Arc1 Arc19 ../data/304
# Arc1 Arc12bis ../data/304
# Arc1 Arc113 ../data/304
# Arc1 Arc114 ../data/304
# Arc1 Arc13 ../data/304
# Arc1 Arc14 ../data/304
# Arc1 Arc111 ../data/304
# Arc11 Arc113 ../data/304
# Arc11 Arc114 ../data/304
# Arc11 Arc111 ../data/304
# Arc111 Arc111 ../data/304
# Arc113 Arc113 ../data/304
# Arc114 Arc114 ../data/304
# GouffreDuRobinet GouffreDuRobinet ../data/304
# CuevaDelSol CuevaDelSol ../data/304
# Arc19 Arc19 ../data/304
# Arc18 Arc18 ../data/304
# Arc17 Arc17 ../data/304
# ResurgenceDeLAvenir ResurgenceDeLAvenir ../data/304
# OjoDeLaMadre OjoDeLaMadre ../data/108
# OmbligoDeLaMadre OmbligoDeLaMadre ../data/108
# Sumidero SumideroPiquante ../data/211
# Sumidero SumideroJuanito ../data/205
# Sumidero SumideroFuturo ../data/304
# Sumidero SumideroEscondido ../data/304
# Sumidero SumideroDelChorizoPlastico ../data/201
# LagrimasDeLaMadre LagrimasDeLaMadre ../data/108
# Sumidero SumideroPiquante ../data/211
# Sumidero SumideroJuanito ../data/205
# Sumidero SumideroFuturo ../data/304
# Sumidero SumideroEscondido ../data/304
# Sumidero SumideroDelChorizoPlastico ../data/201
# Sumidero SumideroPiquante ../data/211
# Sumidero SumideroJuanito ../data/205
# Sumidero SumideroFuturo ../data/304
# Sumidero SumideroEscondido ../data/304
# Sumidero SumideroDelChorizoPlastico ../data/201
# Sumidero SumideroPiquante ../data/211
# Sumidero SumideroJuanito ../data/205
# Sumidero SumideroFuturo ../data/304
# Sumidero SumideroEscondido ../data/304
# Sumidero SumideroDelChorizoPlastico ../data/201
# Sumidero SumideroPiquante ../data/211
# Sumidero SumideroJuanito ../data/205
# Sumidero SumideroFuturo ../data/304
# Sumidero SumideroEscondido ../data/304
# Sumidero SumideroDelChorizoPlastico ../data/201
# Perte3 Perte3 ../data/201
# GB1 GB1 ../data/201
# GB1 GB1bis ../data/201
# GB2 GB2 ../data/201
# GB3 GB3 ../data/201
# Perte2 Perte2 ../data/201
# GBTrou1 GBTrou1 ../data/201
# GBTrou2 GBTrou2 ../data/201
# GBTrou3 GBTrou3 ../data/201
# GouffreDuTotem GouffreDuTotem ../data/201
# DeuxGrottes DeuxGrottes ../data/107
# ChattiereQuiBuffle ChattiereQuiBuffle ../data/107
# MilleEtUneCascade MilleEtUneCascade ../data/107
# GouffreDuCampDuNidDuCondor GouffreDuCampDuNidDuCondor ../data/107
# EmergenceDesTuyaux EmergenceDesTuyaux ../data/107
# Ayayemal Ayayemal ../data/201
# Ayayebo Ayayebo ../data/201
# GB1bis GB1bis ../data/201
# LosGringos LosGringos ../data/209
# GouffreChameau GouffreChameau ../data/107
# PerteDuPointG PerteDuPointG ../data/107
# PuntaBlanca PuntaBlanca ../data/107
# GB-07-02-1 GB-07-02-1 ../data/201
# GB-07-02-2 GB-07-02-2 ../data/201
# GB-07-02-3 GB-07-02-3 ../data/201
# GouffreDuZiploc GouffreDuZiploc ../data/201
# CuevaCaboVertical CuevaCaboVertical ../data/107
# CouleeBlanche CouleeBlanche ../data/107
# BahiaBlanca BahiaBlanca ../data/107
# GrotteDesCanelures GrotteDesCanelures ../data/107
# DuchasDeSanPedro DuchasDeSanPedro ../data/107
# N1 CN16-02-4 ../data/107
# N1 CN16-02-2 ../data/107
# N1 CN16-02-5 ../data/107
# N1 CN16-02-1 ../data/107
# N2 N2 ../data/107
# GouffreCasque GouffreCasque ../data/107
# TroisEntreesPlusUne TroisEntreesPlusUne ../data/109
# SumideroDelChorizoPlastico SumideroDelChorizoPlastico ../data/201
# CN16-02-1 CN16-02-1 ../data/107
# CN16-02-2 CN16-02-2 ../data/107
# MadameCafe MadameCafe ../data/107
# CN16-02-4 CN16-02-4 ../data/107
# CN16-02-5 CN16-02-5 ../data/107
# GouffreLagrimas GouffreLagrimas ../data/108
# GouffreDeLArche GouffreDeLArche ../data/211
# GouffreDeLArche GouffreDeLArche ../data/108
# CuevaBarachos CuevaBarachos ../data/109
# CuevaCaliza CuevaCaliza ../data/109
# EnDesespoirDeCause EnDesespoirDeCause ../data/109
# P10 P10 ../data/109
# PetiteGrotte PetiteGrotte ../data/109
# GouffreHalal GouffreHalal ../data/109
# Gouffralail Gouffralail ../data/109
# GrandeTraversee GrandeTraversee ../data/109
# CuevaDeLaMerienda CuevaDeLaMerienda ../data/109
# Gauges Gauges ../data/109
# Pissotiere Pissotiere ../data/109
# TroisEntreesPlusUne TroisEntreesPlusUne ../data/109
# QuatreEntreesPlusUne QuatreEntreesPlusUne ../data/109
# PuntaBlanca PuntaBlanca ../data/107
# TrouDeLaChattiere TrouDeLaChattiere ../data/109
# ResurgenceHongo ResurgenceHongo ../data/107
# PN01 PN01 ../data/107
# PN02 PN02 ../data/107
# GouffreJackpot GouffreJackpot ../data/107
# PerteCirque4 PerteCirque4 ../data/107
# PetiteChinoise PetiteChinoise ../data/109
# CuevaCascada CuevaCascada ../data/107
# ParaisoDeLasDuchas ParaisoDeLasDuchas ../data/109
# Traversee GrandeTraversee ../data/109
# ResurgenceFinDeSeno ResurgenceFinDeSeno ../data/210
# LosTresRios LosTresRios ../data/106
# HaciendasSalinas HaciendasSalinas ../data/106
# CuevaDelDragon CuevaDelDragon ../data/106
# CuevaDelZorro CuevaDelZorro ../data/106
# GrotteFinistere GrotteFinistere ../data/213
# PerteGlaciaire PerteGlaciaire ../data/213
# CuevaTorseOublie CuevaTorseOublie ../data/209
# PozoAlRato PozoAlRato ../data/209
# PozoDeLosCinquetenos PozoDeLosCinquetenos ../data/209
# PerteDesSabliers PerteDesSabliers ../data/209
# ResurgenceLobos ResurgenceLobos ../data/207
# SystemeCondors SystemeCondors ../data/207
# SystemeCondors SystemeCondors ../data/207
# GouffrePetitCreux GouffrePetitCreux ../data/206

# %%
A_REVOIR = NOUVELLE_SYNTHESE[pd.DataFrame(IN_FOLDER, columns = ['NAME','COND'])['COND']==False]

# %%
A_REVOIR.to_csv('../data/cadastre/Cavites_Non_Attribuees.csv')

# %%
A_REVOIR.head()
# Out:
#        CAD_NUM              NomCadastre              Nom_complet  \
# 6          NAN               PequinaSud              Pequina Sud
# 16  ENT_209004       Perte de l'Acharné       Perte de l'Acharné
# 17         NAN           Perte sans nom           Perte sans nom
# 18  ENT_209005              Perte n° 18              Perte n° 18
# 25         NAN  Grotte du bout du monde  Grotte du bout du monde
#
#     X (UTM 18 Sud)  Y (UTM 18 Sud) Alt.  Dev. Topo Termine? Dev.estimé Prof.  \
# 6              NaN             NaN  NaN        NaN      oui         20   -17
# 16        473027.0       4425450.0  334        NaN      oui         45   -43
# 17             NaN             NaN  NaN        NaN      oui         25   -15
# 18        473067.0       4425846.0  422       57.0      oui        NaN   -34
# 25             NaN             NaN   40      125.0      non        NaN   -15
#
#       UP                        Commentaire Explorateurs
# 6   2008                                NaN          NaN
# 16  2008                                NaN          NaN
# 17  2008  30 mètres au dessus de la Détente          NaN
# 18  2008                                NaN          NaN
# 25  2008                   arrêt sur rien!           NaN
