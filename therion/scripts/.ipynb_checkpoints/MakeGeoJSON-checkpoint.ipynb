# %%
import os
from os.path import isfile, join, dirname, abspath
import sys
import re
import argparse
import shutil
import subprocess
import tempfile
import pandas as pd

import shapefile
from json import dumps
import pyproj as proj
transformer = proj.Transformer.from_crs("epsg:32718", "epsg:4326")

# produce the cave centrelines

CONFIG_FILE = """
source ../data/index.th

export map -fmt esri -o ../data/gis
export model -fmt esri -o ../data/gis

export database -o ../data/gis/database.csv
"""



# write temporary config file
with open("temp.thconfig", 'w') as f:
    f.write(CONFIG_FILE)
    f.close()
subprocess.check_output("therion temp.thconfig", shell = True)
subprocess.check_output("rm temp.thconfig", shell = True)
subprocess.check_output("rm therion.log", shell = True)

CONFIG_FILE = """
source ../data/{sector}/{survey}/{survey}.th
export model -fmt survex -o temp.3d
"""

def findSurvey(CAD_NUM):
    try:
        SURVEY_ADDRESS = database[[(CAD_NUM in value) for value in database['From'].values]]['To'].values[0]
        SURVEY = SURVEY_ADDRESS.split('@')[1].split('.')[-1]
    except IndexError:
        SURVEY = "NaN"
    return SURVEY

def getDepthLength(CAD_NUM):
    SURVEY = findSurvey(CAD_NUM)
    if SURVEY != "NaN" and SURVEY !='(null)':
        print(SURVEY)
        with open('temp.thconfig', 'w') as f:
            FORMATTED = CONFIG_FILE.format(sector = CAD_NUM.split('ENT_')[1][:3], survey =SURVEY)
            f.write(FORMATTED)
            f.close()

        subprocess.check_output("therion temp.thconfig", shell = True)
        subprocess.check_output("rm temp.thconfig", shell = True)
        subprocess.check_output("rm temp.3d", shell = True)

        # open the log and get the depth.

        with open("therion.log", 'r') as f:
            LOG = f.readlines()

            for LINE in LOG:
                if "Total length of survey legs" in LINE:
                    NUMS = LINE.split("Total length of survey legs =")[1].strip(" ")
                    print(NUMS.split('(')[0].strip(" ").strip("m"))
                    LENGTH = float(NUMS.split('(')[0].strip(" ").strip("m"))
                elif "Vertical range" in LINE:
                    DEPTH = float(LINE.split(" ")[4].strip('m'))

            f.close()
        subprocess.check_output("rm therion.log", shell = True)


    else:
        DEPTH = "NaN"
        LENGTH = "NaN"
    return (LENGTH,DEPTH)

# read the database
database =  pd.read_csv('../data/gis/database.csv')

# read the synthesis
SYNTHESE = pd.read_csv('../data/SYNTHESE_POINTAGES.csv')

#SYNTHESE = DATA[['CAD_NUM','NomCadastre','Alt.','Dev. Topo','Prof.','UP','Explorateurs']]


reader = shapefile.Reader("../data/gis/stations3d.shp")
fields = reader.fields[1:]
field_names = [field[0] for field in fields]
POINTS_FIXES = []

for sr in reader.shapeRecords():
    atr = dict(zip(field_names, sr.record))
    # filter by centerline

    if 'ENT' in atr['_NAME']:
        
        try:
            vals = (SYNTHESE[SYNTHESE['CadNum'] == atr['_NAME']].values[0])
            print(vals)
            LENGTH,DEPTH = getDepthLength(atr['_NAME'])
            if LENGTH != 'NaN':
                atr['_LENGTH'] = "{:.0f}".format(LENGTH)
                atr['_DEPTH'] = "{:.0f}".format(DEPTH)
            else:
                atr['_LENGTH'] = str(vals[7])
                atr['_DEPTH'] = str(vals[8])
            
            ROOT  = 'https://tr1813.github.io/ultima-patagonia-topo/therion/data/'
            CAVE_URL = ROOT+vals[0].strip('ENT_')[:3]+'/'+vals[1]+'/'+vals[1]+'.html'
            print(CAVE_URL)
            atr['_CAD_NUM'] = vals[0].strip('ENT_')
            atr['_CAVENAME'] = vals[1]
            atr['_ALTITUDE'] = str(vals[6])
            atr['_EXPED'] = vals[10]
            atr['_EXPLORATEURS'] = str(vals[9])
            atr['_URL'] = "{}".format(CAVE_URL)
        except (IndexError,TypeError):
            atr['_CAD_NUM'] = atr['_NAME'].strip('ENT_')
            atr['_CAVENAME'] = 'not known'
            atr['_LENGTH'] = "not known"
            atr['_DEPTH'] = "not known"
            atr['_ALTITUDE'] = "not known"
            atr['_EXPED'] = "not known"
            atr['_EXPLORATEURS'] = "not known"
            atr['_URL'] = "not known"
            pass

        #print(atr)
        geom = sr.shape.__geo_interface__
        X,Y = geom['coordinates']

        X2,Y2 =  transformer.transform(X,Y)
        geom['coordinates'] = (Y2,X2)


        POINTS_FIXES.append(dict(type="Feature", geometry=geom, properties=atr))

geojson = open("../data/gis/points_fixes.js", "w")
geojson.write("var pointsFixes = \n")
geojson.write(dumps({"type": "FeatureCollection", "features": POINTS_FIXES}, indent=2) + "\n")
geojson.close()
# Out:
# ['ENT_101001' 'Abri' 'Abri2' 'Occupation humaine' 476162.0 4461336.0 '2'
#  nan nan nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/101/Abri/Abri.html
# ['ENT_102001' 'Porche' 'Porche' '3 entrées' 476260.0 4449342.0 '30' nan
#  nan nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/102/Porche/Porche.html
# ['ENT_102002' 'Punta espolon' 'PuntaEspolon'
#  "Exploration Anthony, Yannick, Gelo et Franck, lors de l'incursion sur le Pacifique du 05-02-17. Petite cavité de pied de falaise, rejoignant plusieurs entrées. Un passage inférieur permet de rejoindre un petit actif, se terminant de part et d'autre sur siphon. Explo terminée."
#  474766.0 4451367.0 'ca 50 m' nan '??' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/102/Punta espolon/Punta espolon.html
# ['ENT_104001' 'Abri' 'Abri1' 'Occupation humaine' 475478.0 4450597.0 '5'
#  nan nan nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/104/Abri/Abri.html
# ['ENT_104002' 'Cueva Rien' 'CuevaRien' '3 grottes' 475729.0 4450525.0 nan
#  nan nan nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/104/Cueva Rien/Cueva Rien.html
# ['ENT_105001' 'Cueva Rapido2' 'CuevaRapido2' '2 entrées' 482677.0
#  4454593.0 '30' nan '30' nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/105/Cueva Rapido2/Cueva Rapido2.html
# ['ENT_105002' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106001' nan nan nan nan nan nan nan nan nan nan]
# CuevaPirates
# 370.41
# ['ENT_106002' 'Porche' 'Porche' 'Porche' 490289.0 4451286.0 '70' nan nan
#  nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/106/Porche/Porche.html
# ['ENT_106003' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106004' 'Cueva Nutria' 'CuevaNutria' 'Occupation humaine' 490541.0
#  4453870.0 '20' nan '20' nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/106/Cueva Nutria/Cueva Nutria.html
# ['ENT_106005' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106006' 'Grotte' 'Grotte' nan 490604.0 4450548.0 nan nan nan nan
#  '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/106/Grotte/Grotte.html
# ['ENT_106008' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106009' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106010' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106011' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106012' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106013' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106014' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106015' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106016' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106017' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106018' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_106019' 'Los Tres Rios' 'LosTresRios' nan 488833.0 4451227.0 '325'
#  nan nan nan '2006ITA']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/106/Los Tres Rios/Los Tres Rios.html
# ['ENT_106020' ' Cueva del Dragon' 'CuevaDelDragon' nan 489409.0 4452098.0
#  '187' nan nan nan '2006ITA']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/106/ Cueva del Dragon/ Cueva del Dragon.html
# ['ENT_106021' ' Cueva del Zorro' 'CuevaDelZorro' nan 490088.0 4452354.0
#  '105' nan nan nan '2008ENG']
# CuevaDelZorro
# 159.88
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/106/ Cueva del Zorro/ Cueva del Zorro.html
# ['ENT_107001' 'Cueva des los Pescadores' 'CuevaDesLosPescadores'
#  'résurgence' 482449.0 4444663.0 '40' 200.0 '40' nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Cueva des los Pescadores/Cueva des los Pescadores.html
# ['ENT_107002' 'Résurgence XXX' 'ResurgenceXXX'
#  'Résurgence sous le niveau de la mer' 478634.0 4447073.0 '0' 220.0 '24'
#  nan '2017']
# BahiaBlanca
# 444.00
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Résurgence XXX/Résurgence XXX.html
# ['ENT_107003' 'Deux grottes (double entree)' 'DeuxGrottes'
#  'Repéré le 25-01 par Buldo' 478906.0 4446437.0 '?' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Deux grottes (double entree)/Deux grottes (double entree).html
# ['ENT_107004' 'Chattiere qui buffle' 'ChattiereQuiBuffle'
#  'Arrêt sur rien, à poursuivre (prendre equipement)' 482761.0 4445427.0
#  '?' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Chattiere qui buffle/Chattiere qui buffle.html
# ['ENT_107005' 'Gouffre de la grotte ' 'GouffreDeLaGrotte'
#  'A descendre. Repéré le 25-02-2017 par Natalia, Jean Marc, Laurent, Joël (Nord camp du nid du condor)'
#  479065.0 4447905.0 '436' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Gouffre de la grotte /Gouffre de la grotte .html
# ['ENT_107006' 'Emergence des tuyaux ( rameur)' 'EmergenceDesTuyaux'
#  "(pas sûr des coordonnées utm) (coordonnées : 50°077223 - 075°18.0107) Dans la baie d'accès au plateau nord, coté ouest. Au pied de falaise. Escalade possiblement à faire ( escalade faite par lionel ,denis,david)"
#  479490.0 4447336.0 '?' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Emergence des tuyaux ( rameur)/Emergence des tuyaux ( rameur).html
# ['ENT_107007' 'Gouffre du camp du nid du condor'
#  'GouffreDuCampDuNidDuCondor' 'Etroit.. Mais continue!! Impenetrable'
#  479389.0 4447402.0 '311' nan '15' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Gouffre du camp du nid du condor/Gouffre du camp du nid du condor.html
# ['ENT_107008' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_107009' 'Gouffre du Chameau' 'GouffreChameau'
#  'A proximité du camp du champignon, arrêt sur trop étroit à la cote -113m'
#  479556.0 4447204.0 '380' 162.0 '113' nan '2017']
# GouffreChameau
# 162.06
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Gouffre du Chameau/Gouffre du Chameau.html
# ['ENT_107010' 'perte du Point G' 'PerteDuPointG'
#  'Bouché, débit de perte lors de la recon environ 5 L-s' 478796.0
#  4448311.0 '420' nan '20' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/perte du Point G/perte du Point G.html
# ['ENT_107011' "Cueva d'el cabo vertical" 'CuevaCaboVertical'
#  "Exploration Anthonyet Denis lors de l'incursion sur le Pacifique du 05-02-17.Explo y topo 15-02,Natalia,Buldo,Anton,Richard y Angel. Terminado.Gran porche con tubo-fisura ascendente por el lado sur con pequeño aporte que se cierra. Al norte rampa que lleva a tubo horizontal de buen tamaño, que termina en un pozo de 8 m. que enfrente recibe aporte que abajo del pozo se sifona."
#  476133.0 4447399.0 '39' 345.0 '18--14' nan '2017']
# CuevaCaboVertical
# 344.78
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Cueva d'el cabo vertical/Cueva d'el cabo vertical.html
# ['ENT_107012' 'Porche de la coulée blanche' 'CouleeBlanche'
#  "Le grand porche visible en entrant à droite dans la Bahia Blanca. Repéré par Jean-Marc, Jo, Laurent et Franck. Escalade, topo et explo par Yann et Yannick le 13-02017. Escalade de 20 m derrière le porche d'entrée permet de prendre pied dans un méandre, menant d'un côté à un autre porche en hauteur et de l'autre continue. Explo en cours."
#  482764.0 4445438.0 '25 (estimation)' 84.0 '26' nan '2017']
# CouleeBlanche
# 244.94
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Porche de la coulée blanche/Porche de la coulée blanche.html
# ['ENT_107013' 'Grotte des Canelures' 'GrotteDesCanelures'
#  "Repérée et explorée le 13-02-17 par  Serge, José, Jean-François, Natalia et Franck. Vaste porche visible de la plage, au départ de l'accès au camp Nord. Montée en 15 min par la forêt puis le long d'une canelure. Méandre parcouru par un faible filet d'eau, exploré sur 50 m sur une branche et 20 sur une autre. Arrêt sur passage étroit, l'explo peut être considérée comme terminée."
#  478876.0 4447299.0 '106, donnée GPS surestimée' nan '15' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Grotte des Canelures/Grotte des Canelures.html
# ['ENT_107014' 'Las Duchas de San Pedro' 'DuchasDeSanPedro'
#  "Découverte par Natalia, Laurent, Jean-Marc et Joël. Deux entrée reliée patr une galerie exondée. Un siphon amont exploré depuis l'entrée inférieur, sûrement en connection avec celui de l'entrée supérieure, mais jonction non faite. Le siphon descend jusqu'à -20, remonte à -5 vers la seconde entrée, puis redescend à -13, terminus des explos. *Siphon de 96 m, -20. "
#  482357.0 4446971.0 'ca 50 m' 268.0 '45 (-41, +4)' nan '2017']
# DuchasDeSanPedro
# 267.68
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Las Duchas de San Pedro/Las Duchas de San Pedro.html
# ['ENT_107015' 'Été austral ' 'EteAustral'
#  ' Découvert et descendu par Anthonie et Yannick le 7 février ' 480135.0
#  4447658.0 '411' 105.0 '83' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Été austral /Été austral .html
# ['ENT_107016' 'Trou du carnet ' 'TrouDuCarnet'
#  'descendu par Yannick pour remonté le carnet tombé par Vicenté le 7 février'
#  480211.0 4447632.0 '429' nan '10' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Trou du carnet /Trou du carnet .html
# ['ENT_107017' 'N2' 'N2' 'Prospection et visite , José, Serge et Yannick '
#  482762.0 4445436.0 '?' nan '0' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/N2/N2.html
# ['ENT_107018' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_107019' 'Gouffre du casque' 'GouffreCasque' '1389m de topo' 479879.0
#  4447862.0 '347' 1600.0 '203' nan '2017']
# GouffreCasque
# 1389.18
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Gouffre du casque/Gouffre du casque.html
# ['ENT_107020' 'CN 16-02-1' 'CN16-02-1' 'Gros gouffre, arrêt à -40'
#  479373.0 4446955.0 '387' nan '40' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/CN 16-02-1/CN 16-02-1.html
# ['ENT_107021' 'CN 16-02-2' 'CN16-02-2' 'Gros porche avec arrêt sur étroit'
#  479569.0 4447160.0 '387' nan '15' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/CN 16-02-2/CN 16-02-2.html
# ['ENT_107022' 'Madame Café' 'MadameCafe' nan 479547.0 4447215.0 '384' 66.0
#  '47' nan '2017']
# MadameCafe
# 66.00
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Madame Café/Madame Café.html
# ['ENT_107023' 'CN 16-02-4' 'CN16-02-4' 'Gouffre, arrêt à -25' 479795.0
#  4447413.0 '405' nan '25' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/CN 16-02-4/CN 16-02-4.html
# ['ENT_107024' 'CN 16-02-5' 'CN16-02-5'
#  'Trou près du camp nord 3 avec du débit. Il keut à -15' 479591.0
#  4447357.0 '383' nan '15' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/CN 16-02-5/CN 16-02-5.html
# ['ENT_107025' nan nan nan nan nan nan nan nan nan nan]
# ResurgenceHongo
# 358.00
# ['ENT_107026' 'PN01' 'PN01' nan 477817.0 4446753.0 '60' nan '10' nan
#  '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/PN01/PN01.html
# ['ENT_107027' 'PN02' 'PN02' nan 477795.0 4446685.0 '60' nan '15' nan
#  '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/PN02/PN02.html
# ['ENT_107028' 'Gouffre Jackpot' 'GouffreJackpot' nan 482804.0 4447950.0
#  '369' nan '265' nan '2019']
# GouffreJackpot
# 701.63
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Gouffre Jackpot/Gouffre Jackpot.html
# ['ENT_107029' 'PC4 - Perte Cirque 4' 'PerteCirque4' nan 482664.0 4447782.0
#  '362' nan '12' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/PC4 - Perte Cirque 4/PC4 - Perte Cirque 4.html
# ['ENT_107030' 'Cueva Cascada' 'CuevaCascada' nan 478605.0 4447058.0 nan
#  nan '52' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Cueva Cascada/Cueva Cascada.html
# ['ENT_107031' 'Punta Blanca' 'PuntaBlanca' nan 478574.0 4446622.0 nan nan
#  nan nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/107/Punta Blanca/Punta Blanca.html
# ['ENT_108001' 'Ojo de la Madre' 'OjoDeLaMadre'
#  'Perte très arrosée, fin sur siphon bas etroit ; depôts fluvio-glaciaires ; spéléothèmes prélevés'
#  484150.0 4446766.0 '406' 190.0 '49' nan '2017']
# OjoDeLaMadre
# 185.91
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Ojo de la Madre/Ojo de la Madre.html
# ['ENT_108002' 'Ombligo de la Madre' 'OmbligoDeLaMadre'
#  'Belle perte ; 30m x 10m, tube incliné à 45°, rivière cascadante 200L-s. Arrêt sur siphon etroit. '
#  484295.0 4447150.0 '365' 283.0 '146' nan '2017']
# OmbligoDeLaMadre
# 282.95
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Ombligo de la Madre/Ombligo de la Madre.html
# ['ENT_108003' 'Sumidero ' 'Sumidero'
#  'Perte active mais dans doline bouchée par éboulement et bois. ' 484486.0
#  4447573.0 nan nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Sumidero /Sumidero .html
# ['ENT_108004' 'Gouffre Lagrimas' 'GouffreLagrimas' nan 484396.0 4447498.0
#  '350' nan '150' nan '2019']
# LagrimasDeLaMadre
# 354.83
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Gouffre Lagrimas/Gouffre Lagrimas.html
# ['ENT_108005' 'Sumidero' 'Sumidero'
#  'Perte active mais dans doline bouchée par éboulement et bois. ' 484535.0
#  4448170.0 '198' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Sumidero/Sumidero.html
# ['ENT_108006' 'Garganta' 'Garganta'
#  'Grand porche 20mx20m ; rivière 1m3-s ; très prometteur, à explorer'
#  484595.0 4448213.0 '180' nan nan nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Garganta/Garganta.html
# ['ENT_108007' 'Sumidero' 'Sumidero'
#  'Perte active mais dans doline bouchée par éboulement et bois. ' 484633.0
#  4448258.0 '191' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Sumidero/Sumidero.html
# ['ENT_108008' 'Utero de la Madre' 'Utero de la Madre'
#  "Descendu sans corde jusqu'au siphon, beaux volumes, rivière active ; traces des inventeurs retrouvées ; shunt possible du siphon par escalade de 4m dans une galerie sup. "
#  484956.0 4448483.0 '220' 770.0 'xxx 182' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Utero de la Madre/Utero de la Madre.html
# ['ENT_108009' 'Sumidero' 'Sumidero'
#  "Beau porche, bouché par effondrement plafond à quelques mètres de l'entrée, aller voir derrière par le dessus des calcaires. "
#  485157.0 4448585.0 '225' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Sumidero/Sumidero.html
# ['ENT_108010' 'Sumidero' 'Sumidero'
#  'Petite perte étroite explorée sur quelques mètres; impénétrable'
#  485495.0 4447616.0 '317' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Sumidero/Sumidero.html
# ['ENT_108011' 'agujero' 'agujero'
#  "Gouffre bordure SE scandinavie, P15 d'entrée, ruissellements, non descendu"
#  486016.0 4447774.0 '290' nan nan nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/agujero/agujero.html
# ['ENT_108012' 'agujero' 'agujero'
#  'Gouffre bordure SETube à 45° de 2m de diamètre non descendu ; ' 483835.0
#  4446220.0 '417' nan nan nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/agujero/agujero.html
# ['ENT_108013' "Gouffre de l'Arche" 'GouffreDeLArche' nan 486742.0
#  4448369.0 '15' nan '15' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/108/Gouffre de l'Arche/Gouffre de l'Arche.html
# ['ENT_109001' 'Grotte des 3 Porches' 'TroisPorches' 'Arrêt sur puits'
#  485618.0 4444774.0 '60' 280.0 '-32-+17' nan '2008']
# TroisPorches
# 279.00
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Grotte des 3 Porches/Grotte des 3 Porches.html
# ['ENT_109002' 'Grotte des 3 Porches' 'TroisPorches' 'Occupation humaine'
#  485602.0 4444774.0 '60' nan nan nan '2008']
# QuatreEntreesPlusUne
# 341.20
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Grotte des 3 Porches/Grotte des 3 Porches.html
# ['ENT_109003' 'Cueva Barachos' 'CuevaBarachos' nan 485779.0 4445842.0
#  '375' nan '8' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Cueva Barachos/Cueva Barachos.html
# ['ENT_109004' 'Cueva Caliza' 'CuevaCaliza' nan 485808.0 4445794.0 '370'
#  nan '100' nan '2019']
# CuevaCaliza
# 217.96
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Cueva Caliza/Cueva Caliza.html
# ['ENT_109005' 'En desespoir de Cause' 'EnDesespoirDeCause' nan 485651.0
#  4445694.0 '384' nan '40' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/En desespoir de Cause/En desespoir de Cause.html
# ['ENT_109006' 'P10' 'P10' nan 486410.0 4445941.0 '414' nan '10' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/P10/P10.html
# ['ENT_109007' 'petite Grotte' 'PetiteGrotte' nan 485737.0 4445148.0 '278'
#  nan '6' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/petite Grotte/petite Grotte.html
# ['ENT_109008' 'Gouffre Halal' 'GouffreHalal' nan 485812.0 4445780.0 nan
#  nan '105' nan '2019']
# GouffreHalal
# 128.28
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Gouffre Halal/Gouffre Halal.html
# ['ENT_109009' "Gouffre A l'Aïl" 'Gouffralail' nan 485537.0 4445627.0 '359'
#  nan '46' nan '2019']
# Gouffralail
# 71.32
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Gouffre A l'Aïl/Gouffre A l'Aïl.html
# ['ENT_109010' 'Gouffre Ma première' 'GouffreMaPremiere' nan 485587.0
#  4445498.0 '319' nan '25' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Gouffre Ma première/Gouffre Ma première.html
# ['ENT_109011' 'Gouffre La Grande Traversée' 'GrandeTraversee' nan 485584.0
#  4445478.0 '319' nan '-4, +11' nan '2019']
# GrandeTraversee
# 86.40
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Gouffre La Grande Traversée/Gouffre La Grande Traversée.html
# ['ENT_109012' 'Cueva de la Merienda' 'CuevaDeLaMerienda' nan 486478.0
#  4445928.0 '388' nan '2' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Cueva de la Merienda/Cueva de la Merienda.html
# ['ENT_109013' 'Gouffre des Gaugés' 'Gauges' nan 485438.0 4445269.0 '300'
#  nan '89' nan '2019']
# Gauges
# 102.39
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Gouffre des Gaugés/Gouffre des Gaugés.html
# ['ENT_109014' 'Gouffre la Pissotière' 'Pissotiere' nan 485816.0 4445878.0
#  '360' nan '24' nan '2019']
# Pissotiere
# 38.77
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Gouffre la Pissotière/Gouffre la Pissotière.html
# ['ENT_109015' 'Grotte des trois entrées plus une' 'TroisEntreesPlusUne'
#  nan 485649.0 4444763.0 '53' nan '-54, +78' nan '2019']
# TroisEntreesPlusUne
# 3241.34
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Grotte des trois entrées plus une/Grotte des trois entrées plus une.html
# ['ENT_109016' 'Gouffre de la Chatiere' 'TrouDeLaChattiere' nan 485795.0
#  4444848.0 '36' nan '36' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Gouffre de la Chatiere/Gouffre de la Chatiere.html
# ['ENT_109017' 'Resurgence de la Petite Chinoise' 'PetiteChinoise' nan
#  486340.0 4445620.0 nan nan '83' nan '2019']
# PetiteChinoise
# 318.00
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Resurgence de la Petite Chinoise/Resurgence de la Petite Chinoise.html
# ['ENT_109018' 'Paraiso de las duchas' 'ParaisoDeLasDuchas' nan 485880.0
#  4445791.0 nan nan '133' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Paraiso de las duchas/Paraiso de las duchas.html
# ['ENT_109019' 'Résurgence 3' 'Résurgence 3' '2 m3-s' 485684.0 4444706.0
#  '0' nan nan nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/109/Résurgence 3/Résurgence 3.html
# ['ENT_201001' 'Résurgence 2 du Canyon' 'Resurgence2DuCanyon'
#  'Arrêt sur galerie exondé post S1 (-4m-30m)' 478266.0 4438945.0 '0' 40.0
#  '-4-+2' nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Résurgence 2 du Canyon/Résurgence 2 du Canyon.html
# ['ENT_201002' 'C4T2' 'C4T2' nan 473138.0 4437000.0 '325' nan nan 'Buldo'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4T2/C4T2.html
# ['ENT_201003' 'Secteur Barros Luco' 'Secteur Barros Luco' nan 473081.0
#  4438618.0 '385' 0.0 '-12' 'José-Vanessa-Buldo-Sergio' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Secteur Barros Luco/Secteur Barros Luco.html
# ['ENT_201004' 'C4T1' 'C4T1' nan 473185.0 4437080.0 '337' nan nan 'Buldo'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4T1/C4T1.html
# ['ENT_201005' 'Cueva 3' 'Cueva3' nan 473614.0 4437045.0 '273' 0.0 '-35'
#  'José-Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 3/Cueva 3.html
# ['ENT_201006' 'Cueva 7' 'Cueva7' nan 473794.0 4437339.0 '294' 0.0 '-35'
#  'José' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 7/Cueva 7.html
# ['ENT_201007' 'Cueva 1' 'Cueva1' nan 473598.0 4437045.0 '290' 0.0 '-30'
#  'José-Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 1/Cueva 1.html
# ['ENT_201008' 'Cueva 11' 'Cueva11' nan 473527.0 4437152.0 '338' 0.0 '-28'
#  'Serge-Jean Phi-Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 11/Cueva 11.html
# ['ENT_201009' 'Cueva du Téléphone' 'CuevaDuTelephone' nan 473512.0
#  4437140.0 '340' 0.0 '-26' 'Vanessa-Serge' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva du Téléphone/Cueva du Téléphone.html
# ['ENT_201010' 'Cueva 8' 'Cueva8' nan 473749.0 4437328.0 '309' 0.0 '-26'
#  'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 8/Cueva 8.html
# ['ENT_201011' 'cueva' 'cueva101' nan 473423.0 4437558.0 '492' 0.0 '-25'
#  'Buldo, José, Jean Phi' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/cueva/cueva.html
# ['ENT_201012' 'C4 Cueva 9' 'C4Cueva 9' nan 473607.0 4437277.0 '385' nan
#  nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 Cueva 9/C4 Cueva 9.html
# ['ENT_201013' 'C4T3' 'C4T3' nan 473066.0 4437002.0 '310' nan nan 'Buldo'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4T3/C4T3.html
# ['ENT_201014' 'cueva' 'cueva102' nan 473378.0 4437631.0 '526' 0.0 '-20'
#  'Buldo, José, Jean phi' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/cueva/cueva.html
# ['ENT_201015' 'Cueva' 'Cueva104' nan 473524.0 4437766.0 '469' 0.0 '-20'
#  'Buldo, José, Jean Phi' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva/Cueva.html
# ['ENT_201016' 'Cueva 10' 'Cueva10' nan 473535.0 4437264.0 '347' 0.0 '-15'
#  'José-Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 10/Cueva 10.html
# ['ENT_201017' 'Secteur Barros Luco' 'Secteur Barros Luco' nan 473581.0
#  4437960.0 '393' 0.0 '-15' 'José-Vanessa-Buldo-Sergio' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Secteur Barros Luco/Secteur Barros Luco.html
# ['ENT_201018' 'Cueva 2' 'Cueva2' nan 473619.0 4437025.0 '268' 0.0 '-15'
#  'José-Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 2/Cueva 2.html
# ['ENT_201019' 'Cueva' 'Cueva105' nan 473196.0 4437124.0 '274' 0.0 '-15'
#  'José, Serge, Vanessa, Buldo, Jean Phi' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva/Cueva.html
# ['ENT_201020' nan nan nan nan nan nan nan nan nan nan]
# Resurgence1
# 197.52
# ['ENT_201021' 'Secteur Barros Luco' 'Secteur Barros Luco' nan 473580.0
#  4437961.0 '393' 0.0 '-10' 'José-Vanessa-Buldo-Sergio' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Secteur Barros Luco/Secteur Barros Luco.html
# ['ENT_201022' 'Cueva 12' 'Cueva12' nan 473519.0 4437155.0 '335' 0.0 '-8'
#  'Serge-Jean Phi-Cédric (porche)' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 12/Cueva 12.html
# ['ENT_201023' 'Cueva 5' 'Cueva5' nan 473690.0 4437099.0 '272' 0.0 '-8'
#  'José-Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 5/Cueva 5.html
# ['ENT_201024' 'Cueva 13' 'Cueva13' nan 473520.0 4437115.0 '8' 0.0 '-8'
#  'Serge-Jean Phi-Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 13/Cueva 13.html
# ['ENT_201025' 'Secteur Barros Luco' 'Secteur Barros Luco' nan 473276.0
#  4437291.0 '412' 0.0 '-8' 'José-Vanessa-Buldo-Sergio' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Secteur Barros Luco/Secteur Barros Luco.html
# ['ENT_201026' 'Porche 2 Os de Baleine' 'PorcheBaleine'
#  "Découverte d'ossements de baleine et de lobos (photos disponibles)"
#  471000.0 4440731.0 '9' 0.0 '15'
#  'Jean Phi-Cédric (os baleine+coquillages)' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Porche 2 Os de Baleine/Porche 2 Os de Baleine.html
# ['ENT_201027' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201028' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201029' 'Cueva 4' 'Cueva4' nan 473670.0 4437075.0 '270' nan nan
#  'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva 4/Cueva 4.html
# ['ENT_201030' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201031' 'C3' 'C3' nan 473587.0 4437133.0 '303' nan nan 'Buldo'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C3/C3.html
# ['ENT_201032' 'C4 Cueva 6' 'C4Cueva6' nan 473735.0 4437228.0 '306' nan nan
#  nan '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 Cueva 6/C4 Cueva 6.html
# ['ENT_201033' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201034' 'Cueva de la casquette' 'CuevaDeLaCasquette'
#  'Entrée étroite de la largeur du corps beau donnantsur un puit vertical style cathédrale de 30m (cavité avec plusieurs entrées)'
#  473652.0 4437656.0 '397' 0.0 '-48' 'Cedric-Vanessa-Serge' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva de la casquette/Cueva de la casquette.html
# ['ENT_201035' 'Trou de la Plaquette' 'TrouDeLaPlaquette'
#  "salle d'effondrement ouverte qui fait au gouffre de la casquette dans un alignement de gouffres qui se suivent vers le Barros Luco"
#  473683.0 4437677.0 '382' 0.0 '-23' 'Cedric-Vanessa-Serge' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Trou de la Plaquette/Trou de la Plaquette.html
# ['ENT_201036' 'C4 Nfissure 0' 'C4Nfissure0' nan 473577.0 4438008.0 '389'
#  nan nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 Nfissure 0/C4 Nfissure 0.html
# ['ENT_201037' 'C4 SansNom 8' 'C4SansNom8' nan 473579.0 4438420.0 '361' nan
#  nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 SansNom 8/C4 SansNom 8.html
# ['ENT_201038' 'C4 SansNom 7' 'C4SansNom7' nan 473601.0 4438564.0 '347' nan
#  nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 SansNom 7/C4 SansNom 7.html
# ['ENT_201039' 'C4 SansNom 6' 'C4SansNom6' nan 473616.0 4438593.0 '342' nan
#  nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 SansNom 6/C4 SansNom 6.html
# ['ENT_201040' 'Porche du Sonnar' 'PorcheDuSonnar' 'arrêt sur éboulis'
#  473599.0 4438718.0 '338' 0.0 '-20' 'Cedric-Jose-JeanPhilippe-Serge'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Porche du Sonnar/Porche du Sonnar.html
# ['ENT_201041' 'C4 SansNom 1' 'C4SansNom1' nan 473407.0 4438857.0 '403' nan
#  nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 SansNom 1/C4 SansNom 1.html
# ['ENT_201042' 'C4 SansNom 4' 'C4SansNom4' nan 473028.0 4438978.0 '312' nan
#  nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 SansNom 4/C4 SansNom 4.html
# ['ENT_201043' 'Gouffre du Colibri' 'GouffreDuColibri'
#  "Gouffre d'éffondrement ouvert avec possibilité de continuation mais éboulis instable (plus grosse entrée de la doline)"
#  473077.0 4439130.0 '313' nan '-30' 'Cedric-Jose-JeanPhilippe-Serge'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Gouffre du Colibri/Gouffre du Colibri.html
# ['ENT_201044' 'C4 SansNom 3' 'C4SansNom3' nan 473044.0 4439162.0 '307' nan
#  nan 'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 SansNom 3/C4 SansNom 3.html
# ['ENT_201045' 'C5 Cueva1' 'C5 Cueva1' nan 473343.0 4439239.0 '391' nan nan
#  'Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C5 Cueva1/C5 Cueva1.html
# ['ENT_201046' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201047' 'Champignon' 'Champignon'
#  'Situé au dessus du camp 5 près du seul champignon du secteur. Gros puit vertical de plus de 40m qui suit une faille'
#  473344.0 4439239.0 '391' 0.0 '-45' 'Cedric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Champignon/Champignon.html
# ['ENT_201048' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201049' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201050' nan nan nan nan nan nan nan nan nan nan]
# ['ENT_201051' 'Perte 3' 'Perte3' 'Explo perminée. Arret à -15' 477006.0
#  4441940.0 nan nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Perte 3/Perte 3.html
# ['ENT_201052' 'GB1' 'GB1' '23-01-2017 non descendu, à faire.' 479866.0
#  4441309.0 '356' nan '?' nan '2017']
# GB01
# 45.85
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB1/GB1.html
# ['ENT_201053' 'GB2' 'GB2' '23-01-2017 non descendu, à faire.' 480018.0
#  4441221.0 '351' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB2/GB2.html
# ['ENT_201054' 'GB3' 'GB3'
#  'P 50, à descendre, 23-01-17, non descendu,à faire' 479883.0 4441642.0
#  '239' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB3/GB3.html
# ['ENT_201055' 'Perte 2' 'Perte2' "Pas d'information" 476404.0 4442053.0
#  nan nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Perte 2/Perte 2.html
# ['ENT_201056' 'GB Trou 1' 'GBTrou1' 'Calcaire' 476668.0 4441599.0 '303'
#  46.0 '41' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB Trou 1/GB Trou 1.html
# ['ENT_201057' 'GB Trou 2' 'GBTrou2' 'Calcaire' 476670.0 4441599.0 '306'
#  nan '15' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB Trou 2/GB Trou 2.html
# ['ENT_201058' 'GB Trou 3' 'GBTrou3' 'Calcaire' 476570.0 4441550.0 '329'
#  nan '25' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB Trou 3/GB Trou 3.html
# ['ENT_201059' 'GB Trou 5' 'GB Trou 5' 'Calcaire' 476811.0 4441550.0 '298'
#  nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB Trou 5/GB Trou 5.html
# ['ENT_201060' 'Gouffre du Totem' 'GouffreDuTotem'
#  'Grosse perte à proximitédu camp GB, descendue jusque -40, arrêt sur trop peur'
#  476555.0 4442064.0 '?' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Gouffre du Totem/Gouffre du Totem.html
# ['ENT_201061' 'Ayayémal' 'Ayayemal' "Pas d'information" 476491.0 4441850.0
#  '292' nan '?' nan '2017']
# Ayayemal
# 53.75
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Ayayémal/Ayayémal.html
# ['ENT_201062' 'Ayayébo' 'Ayayebo'
#  'P28 suivi de 2 puits parallèle, 1 descendu (35m) coté "sec" le 31-01-17 et branche active descendue le 08-02-17, arrêt à -96 sur étroit plein d\'eau'
#  476217.0 4441660.0 '314' 160.0 '96' nan '2017']
# Ayayebo
# 158.61
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Ayayébo/Ayayébo.html
# ['ENT_201063' 'GB1 bis' 'GB1bis'
#  'Au dessus du GB 30-01-2017 1. A explorer' 476293.0 4441568.0 '344' nan
#  '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB1 bis/GB1 bis.html
# ['ENT_201064' 'Gouffre ' 'Gouffre2'
#  'à descendre. P15 avec une fenêtre qui semble donner un accès à un puits parallèle.'
#  476287.0 4441655.0 '364' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Gouffre /Gouffre .html
# ['ENT_201065' 'SANS NOM' 'SANS NOM'
#  "S'ouvre au sommet de la crête. A explorer. Dans zone assez broyée. Etre dos au sommet pour voir l'entrée…"
#  476316.0 4440859.0 '596' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201066' 'SANS NOM' 'SANS NOM'
#  'Gouffre environ 30m à explorer ? Danger, zone broyée, paroies instables…'
#  476028.0 4441666.0 '277' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201067' 'SANS NOM' 'SANS NOM'
#  'Porche qui queute proche du contact calcaire grès' 475784.0 4441912.0
#  '388' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201068' 'GB 07 02-1' 'GB-07-02-1' "Pas d'information" 475808.0
#  4441893.0 '380' nan '30' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB 07 02-1/GB 07 02-1.html
# ['ENT_201069' 'GB 07 02-2' 'GB-07-02-2' "Pas d'information" 475787.0
#  4441900.0 '382' nan '40' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB 07 02-2/GB 07 02-2.html
# ['ENT_201070' 'GB 07 02-3' 'GB-07-02-3' 'Arrêt sur trou foireux délité'
#  476036.0 4441670.0 '295' nan '30' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/GB 07 02-3/GB 07 02-3.html
# ['ENT_201071' 'SANS NOM' 'SANS NOM'
#  'Gouffre borgne avec quelques paliers sans suite' 476576.0 4441740.0
#  '281' 45.0 '43' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201072' 'SANS NOM' 'SANS NOM' 'Petits puits colmaté' 476632.0
#  4441445.0 '378' nan '15' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201073' 'Gouffre du Ziploc' 'GouffreDuZiploc' nan 476597.0 4441532.0
#  '316' 44.0 '30' nan '2017']
# Ziploc
# 44.43
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Gouffre du Ziploc/Gouffre du Ziploc.html
# ['ENT_201074' 'Cueva Harrico' 'CuevaHarrico'
#  'Situada en las paredes sur de Punta Indice;Escalada desde el mar a gran boca; rampa ascendente y llegamos a un tubo con aire que termina cerrandose; Explo (Anton y Angel)'
#  481244.0 4440093.0 '29' 254.0 '+85' nan '2017']
# Haricot
# 254.32
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Cueva Harrico/Cueva Harrico.html
# ['ENT_201075' 'Sumidero del Chorizo Plastico' 'SumideroDelChorizoPlastico'
#  'Sumidero al otro lado del collado al norte del campamento' 475551.0
#  4442964.0 '285' nan '30' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Sumidero del Chorizo Plastico/Sumidero del Chorizo Plastico.html
# ['ENT_201076' 'SANS NOM' 'SANS NOM'
#  'Explorada por( Denis y Anton) Cueva de derrumbe y bloques cercq del Sumidero'
#  475670.0 4442920.0 '323' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201077' 'SANS NOM' 'SANS NOM'
#  'Sima bajada por David y Anton con craneos de Coivos ' 475375.0 4442069.0
#  '430' nan '45' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201078' 'SANS NOM' 'SANS NOM'
#  'Zona de grandes bocas de simas muy interesantes Al menos tres bocas de grqndes dimensiones'
#  475272.0 4442209.0 '460' nan '?' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/SANS NOM/SANS NOM.html
# ['ENT_201079' 'C4 SansNom 10' 'C4SansNom10' nan nan nan nan nan nan nan
#  nan]
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/C4 SansNom 10/C4 SansNom 10.html
# ['ENT_201080' 'Porche 1' 'Porche1'
#  "Porche situé avant la plage du Pacifique sur la rive gauche de la rivière (visible depuis la fin du lapiaz du camp 4, le porche s'ouvre 30 m au-dessus de la rivière) Pas de découverte particulière."
#  470851.0 4437247.0 '13' 0.0 '30' 'Jean Phi-Cédric (Plage Pacifique)'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/201/Porche 1/Porche 1.html
# ['ENT_202001' 'grottes des dauphins' 'GrotteDesDauphins'
#  'Explo et topo Serge , José , Yannick (dessin Yannick )' 481705.0
#  4438320.0 '5' nan '????' nan '2017']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/202/grottes des dauphins/grottes des dauphins.html
# ['ENT_203001' 'Perte du Coypo' 'PerteDuCoypo'
#  'Perte très active présentant de beaux puits et un superbe méandre.'
#  472905.0 4434743.0 '253' 283.0 '-191'
#  'Jean-Francois H, Thomas, Florian, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Perte du Coypo/Perte du Coypo.html
# ['ENT_203002' 'Gouffre Félin' 'GouffreFelin' 'beau réseau de puits'
#  473028.0 4434786.0 '258' 294.0 '-121' 'Olivier T, Isa, Florian, Thomas'
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Gouffre Félin/Gouffre Félin.html
# ['ENT_203003' 'Puits du Bourdon' 'PuitsDuBourdon'
#  'puits donnant sur un superbe méandre cannelé, arrêt sur étroiture'
#  473145.0 4434865.0 '249' 107.0 '-48' 'Isa, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Puits du Bourdon/Puits du Bourdon.html
# ['ENT_203004' 'Gros Trou' 'GrosTrou' "aven s'ouvrant dans le grès"
#  473023.0 4434914.0 '252' 30.0 '-15' 'Isa, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Gros Trou/Gros Trou.html
# ['ENT_203005' 'Résurgence' 'Résurgence'
#  'Résurgence sur faille, impénétrable' 472899.0 4435932.0 '34' nan '0'
#  'Isa, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Résurgence/Résurgence.html
# ['ENT_203006' 'Résurgence' 'Résurgence' 'Résurgence non pénétrable'
#  472591.0 4435495.0 '119' nan '0' 'Isa, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Résurgence/Résurgence.html
# ['ENT_203007' 'Résurgence' 'Résurgence' 'Résurgence non pénétrable'
#  472563.0 4435496.0 '121' nan '0' 'Isa, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Résurgence/Résurgence.html
# ['ENT_203008' 'Aven C301' 'Aven C301' 'P30 non descendu peu interessant'
#  473096.0 4434992.0 '334' nan nan 'Isa, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Aven C301/Aven C301.html
# ['ENT_203009' 'Aven' 'Aven' 'Perte très très intéressante à aller voir'
#  472629.0 4435676.0 '105' nan nan 'Isa, Olivier T' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Aven/Aven.html
# ['ENT_203010' 'Porche 1' 'Porche1' nan nan nan nan nan nan nan nan]
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Porche 1/Porche 1.html
# ['ENT_203011' 'Abri du Gazon' 'AbriDuGazon'
#  'Grand porche 20m de diamètre dans le grès en bord de plage' 470883.0
#  4433935.0 '35' nan '0' 'Olivier T, Florian' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Abri du Gazon/Abri du Gazon.html
# ['ENT_203012' 'Grotte du Nord' 'GrotteDuNord'
#  'Petite cavité en bord de mer avec charbons, ossement, arêtes de poisson'
#  471003.0 4434013.0 '0' nan nan 'Olivier T, Florian' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/203/Grotte du Nord/Grotte du Nord.html
# ['ENT_204001' 'Gouffre de la Gazelle' 'GouffreGazelle' nan nan nan nan nan
#  nan nan nan]
# GouffreGazelle
# 166.90
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Gouffre de la Gazelle/Gouffre de la Gazelle.html
# ['ENT_204002' 'Evêque Cauchon' 'EvequeCauchon'
#  'Découverte par equipe 1 du camp 2 le 02-02-2010. Topographié ensuite par équipe du camp 4. Accés collecteur local, débit >100 L-s'
#  474370.0 4432520.0 '74' 235.0 '-58'
#  'Cédric, Vanessa, Bruno, Didier, Fabien, Stéphane, Denis, Arnauld' '2010']
# EvequeCauchon
# 207.40
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Evêque Cauchon/Evêque Cauchon.html
# ['ENT_204003' 'Grotte de la fausse Pucelle' 'GrotteFaussePucelle'
#  'redécouverte par équipe 1 du camp 2 le 01-02-2010 (découverte "oubliée" (non topo) par Richard et Jo en raid-éclair en 2000 depuis camp perte du Temps), env. 3 m3-s en crue. Située une centaine de mètres en amont (vers l\'est) de la Fausse Pucelle).'
#  475586.0 4431730.0 '130' 117.0 '-30' 'Les doigts bleus' '2010']
# GrotteFaussePucelle
# 116.80
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Grotte de la fausse Pucelle/Grotte de la fausse Pucelle.html
# ['ENT_204004' "Grotte de l'Alouette" 'GouffreAlouette'
#  'explo topo équipe 1 du camp 2 ("les doigts bleus") le 31-01-2010. Gazelle et Alouette communiquent (même sans radio…)'
#  474630.0 4432456.0 '153' nan nan nan '2010']
# GouffreAlouette
# 365.41
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Grotte de l'Alouette/Grotte de l'Alouette.html
# ['ENT_204005' 'Trou des Canelures' 'TrouDesCanelures' nan 473390.0
#  4434247.0 '316' nan nan 'Isa' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Trou des Canelures/Trou des Canelures.html
# ['ENT_204006' 'Perte' 'Perte1' 'Perte à voir ' 473289.0 4434576.0 '305'
#  nan nan 'Olivier T, Isa' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Perte/Perte.html
# ['ENT_204007' 'Perte' 'Perte2' 'Perte à voir' 474168.0 4435461.0 '157' nan
#  nan 'Olivier T, Isa' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Perte/Perte.html
# ['ENT_204008' 'Grotte du Rapace' 'GrotteDuRapace'
#  'joli petit méandre, arrêt sur trémie, deux petits départ laissé, sans grand intérêt'
#  472046.0 4433537.0 '84' 0.0 '6' 'Olivier T, Florian' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Grotte du Rapace/Grotte du Rapace.html
# ['ENT_204009' "Grotte de l'Oursin" 'GrotteDeLOursin'
#  "Résurgence fossile (?) avec gros courant d'air, au pied du lapiaz. Campement nomade probable. Patelles, os, charbons. Colobris trogloxènes morts. Jolies excentriques et concretionnement "
#  471984.0 4433604.0 '50' 175.0 '25'
#  'Olivier T, Isa, Florian, Thomas, Jean Francois H' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Grotte de l'Oursin/Grotte de l'Oursin.html
# ['ENT_204010' 'Grotte de la Cacahuete' 'GrotteCacahuete'
#  'redécouverte par équipe 1 du camp 2 le 01-02-2010 (découverte "oubliée" (non topo) par Richard et Jo en raid-éclair en 2000 depuis camp perte du Temps), située une cinquantaine de mètres en rive droite de la perte de la Jeanne dans un renfoncement de falaise.'
#  nan nan nan 186.0 '-21' 'Les doigts bleus' '2010']
# GrotteCacahuete
# 186.24
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/204/Grotte de la Cacahuete/Grotte de la Cacahuete.html
# ['ENT_205001' 'Abri Cotier' 'AbriCotier' 'Occupation humaine' 468749.0
#  4428616.0 '2' 80.0 '5' nan '2008']
# AbriCotier
# 295.44
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Abri Cotier/Abri Cotier.html
# ['ENT_205002' 'Abri du Cerfeuil' 'AbriDuCerfeuil' 'Occupation humaine'
#  469246.0 4429044.0 '183' nan nan nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Abri du Cerfeuil/Abri du Cerfeuil.html
# ['ENT_205003' 'Cueva La-Bas' 'CuevaLaBas' 'Arrêt sur siphon' 472569.0
#  4429495.0 '270' 429.0 '-233' nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Cueva La-Bas/Cueva La-Bas.html
# ['ENT_205004' 'Perte des Dents' 'PerteDesDents' 'Arrêt sur siphon'
#  472991.0 4429200.0 '250' 505.0 '-160' nan '2008']
# PerteDesDents
# 501.82
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Perte des Dents/Perte des Dents.html
# ['ENT_205005' 'Sima Juanito' 'SumideroJuanito'
#  'arrêt sur rien (attention à la crue)' 472888.0 4429344.0 '233' 205.0
#  '-134' nan '2008']
# SumideroJuanito
# 204.90
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Sima Juanito/Sima Juanito.html
# ['ENT_205006' 'Cueva Ardilla' 'CuevaArdilla' 'Arrêt sur ?' 472675.0
#  4429462.0 '245' nan '-70' nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Cueva Ardilla/Cueva Ardilla.html
# ['ENT_205007' 'Sou30 (pozo 1 en caliza)' 'Sou30' nan 472620.0 4429466.0
#  '237' nan '-35' nan '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Sou30 (pozo 1 en caliza)/Sou30 (pozo 1 en caliza).html
# ['ENT_205008' 'Sou33' 'Sou33' nan 472373.0 4429958.0 '301' 0.0 '-70' nan
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Sou33/Sou33.html
# ['ENT_205009' 'Sou31' 'Sou31' nan 472414.0 4429499.0 '281' 0.0 '-30' nan
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Sou31/Sou31.html
# ['ENT_205010' 'MD-SOU01' 'MD-SOU01' nan 472798.0 4429403.0 '260' nan '-30'
#  nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/MD-SOU01/MD-SOU01.html
# ['ENT_205011' 'MD-SOU02' 'MD-SOU02' nan 472768.0 4429435.0 '265' nan '-35'
#  nan '2008']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/MD-SOU02/MD-SOU02.html
# ['ENT_205012' 'Perte Inattendue' 'PerteInattendue'
#  "Perte sur contact grès calcaires. Un moins un aflfuent pénétrable n'a pas été topographié."
#  472890.0 4429492.0 '294' 1274.0 '-226'
#  'Florence, Laurent, Jo, Olivier T, Thomas, Cédric' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Perte Inattendue/Perte Inattendue.html
# ['ENT_205013' 'La Perte Ambrée' 'PerteAmbree' 'arrêt méandre impénétrable'
#  472672.0 4429457.0 '249' 103.0 '-81' 'Laurent C, Pierre' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/La Perte Ambrée/La Perte Ambrée.html
# ['ENT_205014' 'porche' 'porche' 'Porche jef (voir + bas)' 471557.0
#  4429685.0 '399' nan '?' 'Laurent M' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/porche/porche.html
# ['ENT_205015' 'perte-faille' 'PerteFaille' nan 472343.0 4429312.0 '309'
#  nan '?' 'Laurent M' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/perte-faille/perte-faille.html
# ['ENT_205016' 'sortie traversée' 'sortie traversée' nan 471527.0 4429604.0
#  '415' nan '?' 'Laurent M' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/sortie traversée/sortie traversée.html
# ['ENT_205017' 'Trou serrure entrée' 'Trou serrure entrée' nan 471546.0
#  4429667.0 '407' nan '?' 'Laurent M' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Trou serrure entrée/Trou serrure entrée.html
# ['ENT_205018' 'grotte jef' 'grotte jef' 'h9.5 prof10m long20m' 471601.0
#  4429940.0 '413' nan '?' 'Laurent M' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/grotte jef/grotte jef.html
# ['ENT_205019' 'Aven grd diam' 'Aven grd diam' 'axe probable sur faille'
#  471184.0 4431010.0 '275' nan '?' 'Laurent M' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Aven grd diam/Aven grd diam.html
# ['ENT_205020' 'perte 2' 'perte 2' nan 472620.0 4429463.0 '249' nan '?' nan
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/perte 2/perte 2.html
# ['ENT_205021' 'Perte des 4 champi' 'PerteDesQuatreChampignons'
#  "Exploré mais non topo jusqu'à -200 env. arrêt sur rien" 474306.0
#  4431894.0 '207' 420.0 '-165' 'Sylvain, Cédric, José, Olivier G, Isa, '
#  '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Perte des 4 champi/Perte des 4 champi.html
# ['ENT_205022' 'James Bonde' 'JamesBonde' 'A proximité du Golden Igue'
#  474215.0 4431943.0 '230' 0.0 '-54' 'Florian, Olivier G' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/James Bonde/James Bonde.html
# ['ENT_205023' 'Perte du Jump' 'PerteDuJump' 'Perte sur faille' 474413.0
#  4431894.0 '191' nan '-15' 'Olivier G, Sylvain' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Perte du Jump/Perte du Jump.html
# ['ENT_205024' 'Faille du Coinceur' 'FailleDuCoinceur'
#  "Descente sur un coinceur et un spit: on n'a gâché qu'un seul spit"
#  474282.0 4432118.0 '190' 0.0 '-11' 'Florian' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Faille du Coinceur/Faille du Coinceur.html
# ['ENT_205025' 'Igue du Plouc' 'IgueDuPlouc' '"enfin une igue sur MDD"'
#  474109.0 4432134.0 '200' 0.0 '-9' 'Florian' '2010']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/205/Igue du Plouc/Igue du Plouc.html
# ['ENT_205026' 'Cueva de la fin de Matinas' 'CuevaDeLaFinDeMatinas'
#  "plus de temps à enfiler la combi que d'explo!" 474488.0 4432062.0 '170'
# ...
# ['ENT_304006' 'TC2' 'TC2' 'Colmaté' 493337.0 4308329.0 '488' nan '-30' nan
#  '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/TC2/TC2.html
# ['ENT_304007' 'TC3' 'TC3' 'Colmaté' 492238.0 4307919.0 '544' nan '-65' nan
#  '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/TC3/TC3.html
# ['ENT_304008' 'TC4' 'TC4' 'Impénétrable, à désober' 493149.0 4307944.0
#  '533' nan '0' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/TC4/TC4.html
# ['ENT_304009' 'TC5' 'TC5' nan 493139.0 4307904.0 '533' nan nan nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/TC5/TC5.html
# ['ENT_304010' 'TC6' 'TC6' 'Colmaté' 493149.0 4307879.0 '522' nan nan nan
#  '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/TC6/TC6.html
# ['ENT_304011' 'Gouffre Pacifico' 'GouffrePacifico'
#  'Explo Romain-Seba + Lionel-Natalia + Tigrou-Denis-Steph, topo réalisée'
#  492835.0 4307760.0 '386' nan '-196' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre Pacifico/Gouffre Pacifico.html
# ['ENT_304012' 'Pas de nom' 'Pas de nom' nan 492741.0 4307760.0 '372' nan
#  nan nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Pas de nom/Pas de nom.html
# ['ENT_304013' 'Pas de nom' 'Pas de nom' nan 492538.0 4307322.0 '344' nan
#  nan nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Pas de nom/Pas de nom.html
# ['ENT_304014' 'Pas de nom' 'Pas de nom' nan 492549.0 4307305.0 nan nan nan
#  nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Pas de nom/Pas de nom.html
# ['ENT_304015' 'Perte du col 1' 'PerteDuCol1' 'Puits sur faille' 493740.0
#  4308750.0 nan nan '-30' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Perte du col 1/Perte du col 1.html
# ['ENT_304016' 'Perte du col 2' 'PerteduCol2' 'Extrémité Nord de la faille'
#  493735.0 4308575.0 nan nan '0' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Perte du col 2/Perte du col 2.html
# ['ENT_304017' 'Igue du Midi' 'IgueDuMidi' 'Arrêt sur méandre étroit'
#  493488.0 4308749.0 nan nan '-58' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Igue du Midi/Igue du Midi.html
# ['ENT_304018' 'Igue Enviluc' 'IgueEnviluc' nan 493487.0 4308761.0 nan nan
#  '-13' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Igue Enviluc/Igue Enviluc.html
# ['ENT_304019' 'Cueva de la Mañana' 'CuevaManana' 'Colmatage de grès'
#  493354.0 4308416.0 nan nan '-11' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Cueva de la Mañana/Cueva de la Mañana.html
# ['ENT_304020' 'Trou du Cairn' 'TrouDuCairn' nan 493378.0 4308649.0 nan nan
#  '-40' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Trou du Cairn/Trou du Cairn.html
# ['ENT_304021' 'Gouffre des Trois Arches' 'GouffreDesTroisArches'
#  'Arrêt sur Siphon' 493345.0 4308371.0 '483' nan '-42' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre des Trois Arches/Gouffre des Trois Arches.html
# ['ENT_304022' 'Gouffre "2 spits pour Rien"' 'GouffreDeuxSpitsPourRien' nan
#  492718.0 4307932.0 '358' nan '-33' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre "2 spits pour Rien"/Gouffre "2 spits pour Rien".html
# ['ENT_304023' 'Gouffre No Futur' 'GouffreNoFutur' 'Croquis' 494209.0
#  4303537.0 '438' nan '-40' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre No Futur/Gouffre No Futur.html
# ['ENT_304024' 'Gouffre Retour vers le Futur' 'GouffreRetourVersLeFutur'
#  'Topo, Arrêt sur désob' 494247.0 4303396.0 '412' 133.0 '-61' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre Retour vers le Futur/Gouffre Retour vers le Futur.html
# ['ENT_304025' 'Arc 13' 'Arc13' 'Schéma' 492630.0 4307395.0 '325' nan '-15'
#  nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 13/Arc 13.html
# ['ENT_304026' 'Arc 12' 'Arc12' 'Schéma' 492811.0 4307523.0 '387' nan '-15'
#  nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 12/Arc 12.html
# ['ENT_304027' 'Arc 12bis' 'Arc12bis' 'Schéma' 492811.0 4307523.0 '387' nan
#  '-15' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 12bis/Arc 12bis.html
# ['ENT_304028' 'Arc 3' 'Arc3' 'Schéma' 492744.0 4307438.0 '368' nan '-30'
#  nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 3/Arc 3.html
# ['ENT_304029' 'Arc 4' 'Arc4' 'Schéma' 492791.0 4307449.0 '380' nan '-20'
#  nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 4/Arc 4.html
# ['ENT_304030' 'Gouffre Futur 1' 'SumideroFuturo' 'Voir Schéma Xav'
#  493519.0 4304030.0 '545' nan nan nan '2014']
# SumideroFuturo
# 701.00
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre Futur 1/Gouffre Futur 1.html
# ['ENT_304031' 'Gouffre Futur 2' 'SumideroFuturo' 'Voir Schéma Xav'
#  493402.0 4304216.0 '562' nan '-30' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre Futur 2/Gouffre Futur 2.html
# ['ENT_304032' 'Gouffre N°1 Sommet 3' 'Gouffre N°1 Sommet 3'
#  'Jonctionne avec Gouffre Futur 1 de Tigrou ; Arrêt sur éboulis à -40 m'
#  493524.0 4304050.0 '554' nan '-40' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre N°1 Sommet 3/Gouffre N°1 Sommet 3.html
# ['ENT_304033' 'Pas de nom' 'Pas de nom'
#  'Terminé ; Même gouffre que le Gouffre Futur 2 de Tigrou' 493405.0
#  4304223.0 '557' nan '-30' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Pas de nom/Pas de nom.html
# ['ENT_304034' 'Gouffre n°3 sommet 3' 'Gouffre n°3 sommet 3' 'Terminé'
#  493434.0 4304074.0 '54' nan '-16' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre n°3 sommet 3/Gouffre n°3 sommet 3.html
# ['ENT_304035' 'Machu-Pichu' 'GrotteMachuPichu' 'Topographie' 492079.0
#  4310722.0 nan 214.0 '16 - -4' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Machu-Pichu/Machu-Pichu.html
# ['ENT_304036' 'Gouffre "Un cul de plus à explorer"'
#  'GouffreUnCulDePlusAExplorer' 'A explorer' 492861.0 4307876.0 '399' nan
#  nan nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre "Un cul de plus à explorer"/Gouffre "Un cul de plus à explorer".html
# ['ENT_304037' 'Gouffre près du camp du Futur'
#  'Gouffre près du camp du Futur' 'A Explorer, P20 mini' 494155.0 4303338.0
#  '407' nan '-20' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre près du camp du Futur/Gouffre près du camp du Futur.html
# ['ENT_304038' 'Arc 14' 'Arc14'
#  'P60 à explorer par temps sec, arrêt sur rien' 492564.0 4307349.0 '347'
#  nan '-60' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 14/Arc 14.html
# ['ENT_304039' 'Cueva del Condor' 'SystemaLosTubos'
#  'Altitude estimée ; Systema de los Tubos' 491290.0 4307597.0 '230' nan
#  '-110' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Cueva del Condor/Cueva del Condor.html
# ['ENT_304040' 'Sumdiero Escondido' 'SumideroEscondido' 'A remplir!'
#  490540.0 4306695.0 '106' 174.0 '-55' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Sumdiero Escondido/Sumdiero Escondido.html
# ['ENT_304041' 'Surgencia Estrella' 'SurgenciaEstrella'
#  'Grosse résurgence, 25 m de long, gros siphon à plonger, galerie remontante sur 20 m'
#  492249.0 4307720.0 '65' nan '20' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Surgencia Estrella/Surgencia Estrella.html
# ['ENT_304042' 'Cueva Estrella' 'CuevaEstrella'
#  'Au dessus de la résurgence Estrella, Accés au collecteur entre 2 siphons'
#  492261.0 4307711.0 '95' nan '-30' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Cueva Estrella/Cueva Estrella.html
# ['ENT_304043' 'Perte perdue' 'PertePerdue'
#  'Coordonnées levées sur carte ; Terminée' 490540.0 4306695.0 '106' nan
#  '-10' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Perte perdue/Perte perdue.html
# ['ENT_304044' 'Gouffre "Explorévitefait"' 'GouffreExploreViteFait'
#  'Coordonnées levées sur carte ; Terminée' 490470.0 4306552.0 '101' nan
#  '-60' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre "Explorévitefait"/Gouffre "Explorévitefait".html
# ['ENT_304045' 'Puits 1 Jean-Phi' 'Puits1JeanPhi' 'Altitude estimée'
#  491049.0 4307630.0 '250' nan nan nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Puits 1 Jean-Phi/Puits 1 Jean-Phi.html
# ['ENT_304046' 'Pozo Dyke (System de los Tubas)' 'SystemaLosTubos'
#  'Altitude estimée' 491165.0 4307597.0 nan nan nan nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Pozo Dyke (System de los Tubas)/Pozo Dyke (System de los Tubas).html
# ['ENT_304047' 'Arc 1' 'Arc1' 'Croquis ; Fini' 492098.0 4306813.0 '276' nan
#  '-30' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 1/Arc 1.html
# ['ENT_304048' 'Arc 11' 'Arc11' 'Croquis ; Fini' 492226.0 4306784.0 '260'
#  nan '-30' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 11/Arc 11.html
# ['ENT_304049' 'Arc 111' 'Arc111' 'Croquis ; Fini' 492134.0 4306635.0 '258'
#  nan '-15' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 111/Arc 111.html
# ['ENT_304050' 'Arc 113' 'Arc113' 'Croquis ; Fini' 491671.0 4306206.0 '299'
#  nan '-15' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 113/Arc 113.html
# ['ENT_304051' 'Arc 114' 'Arc114' 'Croquis ; Fini' 491307.0 4306156.0 '259'
#  nan '-20' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 114/Arc 114.html
# ['ENT_304052' "Arc 112 ; Les mystères de l'ouest" 'Arc112'
#  'Topographie faite, arrêt sur Rien, méandre actif, 50 l-S ; A faire par temps Sec !!!'
#  491808.0 4306374.0 '291' 216.0 '-71' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 112 ; Les mystères de l'ouest/Arc 112 ; Les mystères de l'ouest.html
# ['ENT_304053' 'Gouffre du Robinet' 'GouffreDuRobinet'
#  'Topographie effectuée' 493210.0 4307750.0 '456' 230.0 '-91' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Gouffre du Robinet/Gouffre du Robinet.html
# ['ENT_304054' 'Arc 20 ou gouffre du Soleil' 'CuevaDelSol'
#  "Les 30 derniers mètres sont estimés, arrêt sur Rien au sommet d'iun P30, dernier point topo sur AN de début de MC, avec une croix au dessus, P30 difficile à équiper car rien ne tient"
#  492409.0 4307605.0 '212' 140.0 '-100' nan '2014']
# CuevaDelSol
# 105.35
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 20 ou gouffre du Soleil/Arc 20 ou gouffre du Soleil.html
# ['ENT_304055' 'Arc 19' 'Arc19'
#  'Arrêt du etr. En sommet de P10 non descendu' 492487.0 4307678.0 '229'
#  nan '-50' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 19/Arc 19.html
# ['ENT_304056' 'Arc 18' 'Arc18' 'arrêt sur éboulis' 492484.0 4307639.0
#  '224' nan '-37' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 18/Arc 18.html
# ['ENT_304057' 'Arc 17' 'Arc17'
#  'Perte de canelure, importante,P20 mini,  non explorée' 492637.0
#  4307761.0 '300' nan '-20' nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Arc 17/Arc 17.html
# ['ENT_304058' 'Perte Col 1' 'PerteCol1' nan 493722.0 4308518.0 '482' nan
#  nan nan '2014']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/304/Perte Col 1/Perte Col 1.html
# ['ENT_401001' 'Moulin Rêve Bleu' 'MoulinReveBleu' nan 577225.0 4604263.0
#  nan nan '32' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Moulin Rêve Bleu/Moulin Rêve Bleu.html
# ['ENT_401002' 'Perte Saloude' 'PerteSaloude' nan 577141.0 4603383.0 nan
#  nan nan nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Perte Saloude/Perte Saloude.html
# ['ENT_401003' 'Moulin de glace' 'MoulinDeGlace' nan 577289.0 4604031.0
#  '122' nan '8' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Moulin de glace/Moulin de glace.html
# ['ENT_401004' 'Lac 2' 'Lac2' nan 577528.0 4603955.0 nan nan '12' nan
#  '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Lac 2/Lac 2.html
# ['ENT_401005' 'Lac Tic et Tac' 'LacTicEtTac' nan 577555.0 4603901.0 nan
#  nan nan nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Lac Tic et Tac/Lac Tic et Tac.html
# ['ENT_401006' 'Cueva Esperanza' 'CuevaEsperanza' nan 576150.0 4598655.0
#  '250' nan '25' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Cueva Esperanza/Cueva Esperanza.html
# ['ENT_401007' 'Traversée de la Cascade' 'TraverseeDeLaCascade' nan
#  576183.0 4600809.0 nan nan '3' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Traversée de la Cascade/Traversée de la Cascade.html
# ['ENT_401008' "L'abri sous glace" 'AbriSousGlace' nan 576064.0 4600782.0
#  nan nan '2' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/L'abri sous glace/L'abri sous glace.html
# ['ENT_401009' 'Salto del Agua' ' SaltoDelAgua' nan 575588.0 4601180.0 nan
#  nan '8' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Salto del Agua/Salto del Agua.html
# ['ENT_401010' 'Moulin Abou' ' MoulinAbou' nan 575786.0 4601270.0 nan nan
#  '16' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Moulin Abou/Moulin Abou.html
# ['ENT_401011' 'Moulin Tapis Volant' 'MoulinTapisVolant' nan 575977.0
#  4601227.0 nan nan '15' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Moulin Tapis Volant/Moulin Tapis Volant.html
# ['ENT_401012' 'Traversée' 'Traversee' nan 575925.0 4601038.0 nan nan '10'
#  nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Traversée/Traversée.html
# ['ENT_401013' 'Moulin du Champignon' 'MoulinDuChampignon' nan 576005.0
#  4597166.0 nan nan '?' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Moulin du Champignon/Moulin du Champignon.html
# ['ENT_401014' 'Traversee du meandre 1' 'TraverseeDuMeandre1' nan 577950.0
#  4597074.0 nan nan '4' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Traversee du meandre 1/Traversee du meandre 1.html
# ['ENT_401015' 'Traversee du meandre 2' 'TraverseeDuMeandre2' nan 578009.0
#  4597133.0 nan nan '2' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Traversee du meandre 2/Traversee du meandre 2.html
# ['ENT_401016' 'Moulin de glace' 'MoulinDeGlace' nan 576724.0 4597385.0 nan
#  nan '7' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Moulin de glace/Moulin de glace.html
# ['ENT_401017' 'Moulin de la Conception' 'MoulinDeLaConception' nan
#  575986.0 4597099.0 nan nan '?' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Moulin de la Conception/Moulin de la Conception.html
# ['ENT_401018' 'Cueva Tempanos - Entrée 1' 'CuevaTempanosEntree1' nan
#  575384.0 4601618.0 '48' nan '58' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Cueva Tempanos - Entrée 1/Cueva Tempanos - Entrée 1.html
# ['ENT_401019' 'Cueva Tempanos - Entrée 2' 'CuevaTempanosEntree2' nan
#  575379.0 4601714.0 '36' nan nan nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Cueva Tempanos - Entrée 2/Cueva Tempanos - Entrée 2.html
# ['ENT_401020' 'Cueva Tempanos - Entrée 3' 'CuevaTempanosEntrée3' nan
#  575465.0 4601707.0 '58' nan nan nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Cueva Tempanos - Entrée 3/Cueva Tempanos - Entrée 3.html
# ['ENT_401021' 'Fuite Prometteuse' 'FuitePrometteuse' nan 575691.0
#  4601178.0 nan nan '22' nan '2019']
# https://tr1813.github.io/ultima-patagonia-topo/therion/data/401/Fuite Prometteuse/Fuite Prometteuse.html

# %%
for CADNUM in pd.read_csv('../data/SYNTHESE_POINTAGES.csv')['CadNum']:
    SURVEY = findSurvey(CADNUM)
# Out:
# UltimaPatagonia
# UltimaPatagonia
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# CuevaPirates
# CuevaPirates
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# CuevaDelZorro
# CuevaDelZorro
# NaN
# BahiaBlanca
# BahiaBlanca
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# GouffreChameau
# GouffreChameau
# NaN
# CuevaCaboVertical
# CuevaCaboVertical
# CouleeBlanche
# CouleeBlanche
# NaN
# DuchasDeSanPedro
# DuchasDeSanPedro
# NaN
# NaN
# NaN
# NaN
# GouffreCasque
# GouffreCasque
# NaN
# NaN
# MadameCafe
# MadameCafe
# NaN
# NaN
# ResurgenceHongo
# ResurgenceHongo
# NaN
# NaN
# GouffreJackpot
# GouffreJackpot
# NaN
# NaN
# NaN
# OjoDeLaMadre
# OjoDeLaMadre
# OmbligoDeLaMadre
# OmbligoDeLaMadre
# NaN
# LagrimasDeLaMadre
# LagrimasDeLaMadre
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# TroisPorches
# TroisPorches
# QuatreEntreesPlusUne
# QuatreEntreesPlusUne
# NaN
# CuevaCaliza
# CuevaCaliza
# NaN
# NaN
# NaN
# GouffreHalal
# GouffreHalal
# Gouffralail
# Gouffralail
# NaN
# GrandeTraversee
# GrandeTraversee
# NaN
# Gauges
# Gauges
# Pissotiere
# Pissotiere
# TroisEntreesPlusUne
# TroisEntreesPlusUne
# NaN
# PetiteChinoise
# PetiteChinoise
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# Resurgence1
# Resurgence1
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# GB01
# GB01
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# Ayayemal
# Ayayemal
# Ayayebo
# Ayayebo
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# Ziploc
# Ziploc
# Haricot
# Haricot
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# GouffreGazelle
# GouffreGazelle
# EvequeCauchon
# EvequeCauchon
# GrotteFaussePucelle
# GrotteFaussePucelle
# GouffreAlouette
# GouffreAlouette
# NaN
# NaN
# NaN
# NaN
# NaN
# GrotteCacahuete
# GrotteCacahuete
# AbriCotier
# AbriCotier
# NaN
# NaN
# PerteDesDents
# PerteDesDents
# SumideroJuanito
# SumideroJuanito
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# GrotteAudeline
# GrotteAudeline
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# PozoDelContacto
# PozoDelContacto
# NaN
# NaN
# NaN
# NaN
# PerteDuMoral
# PerteDuMoral
# P85Camp400
# P85Camp400
# CuevaComete
# CuevaComete
# NaN
# NaN
# NaN
# NaN
# PerteDeLaRiviere
# PerteDeLaRiviere
# Passoire
# Passoire
# GouffrePetitCreux
# GouffrePetitCreux
# PerteDuTemps
# PerteDuTemps
# NaN
# SystemeCondors
# SystemeCondors
# ResurgenceLobos
# ResurgenceLobos
# Cueva10H10
# Cueva10H10
# NaN
# NaN
# NaN
# NaN
# GrotteDuPleinCintre
# GrotteDuPleinCintre
# EmergenceBarillet
# EmergenceBarillet
# NaN
# NaN
# NaN
# ResurgenceDeLaPlage
# ResurgenceDeLaPlage
# GrotteEvier
# GrotteEvier
# LosGringos
# LosGringos
# NaN
# GouffreDeLaDetente
# GouffreDeLaDetente
# NaN
# NaN
# NaN
# GouffreCumpleAnos
# GouffreCumpleAnos
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# PozoAlRato
# PozoAlRato
# PozoDeLosCinquetenos
# PozoDeLosCinquetenos
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# CuevaTorseOublie
# CuevaTorseOublie
# NaN
# NaN
# NaN
# NaN
# PerteDesSabliers
# PerteDesSabliers
# ResurgenceFinDeSeno
# ResurgenceFinDeSeno
# AbrigoDelViento
# AbrigoDelViento
# SumideroPiquante
# SumideroPiquante
# GouffreAguilucho
# GouffreAguilucho
# ExsurgencePicaflor
# ExsurgencePicaflor
# PorcheDeLImpatience
# PorcheDeLImpatience
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# Gouffre36
# Gouffre36
# GouffreDesMousquetaires
# GouffreDesMousquetaires
# GouffreDeLArche
# GouffreDeLArche
# NaN
# NaN
# NaN
# GrotteMarion
# GrotteMarion
# MeandreDesSables
# MeandreDesSables
# NaN
# NaN
# AvenDeLaTraverse
# AvenDeLaTraverse
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# (null)
# (null)
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# PerteGlaciaire
# PerteGlaciaire
# NaN
# PerteDesPortesDAbraham
# PerteDesPortesDAbraham
# CuevaNutria
# CuevaNutria
# NaN
# NaN
# CuevaTortillaConCitron
# CuevaTortillaConCitron
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# PerteDeLaSucriereInferieure
# PerteDeLaSucriereInferieure
# ResurgenceDeLAvenir
# ResurgenceDeLAvenir
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# SumideroFuturo
# SumideroFuturo
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# CuevaDelSol
# CuevaDelSol
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN

# %%
reader = shapefile.Reader("../data/gis/shots3d.shp")
fields = reader.fields[1:]
field_names = [field[0] for field in fields]
SURVEY_LINES = []

for sr in reader.shapeRecords():
    atr = dict(zip(field_names, sr.record))
    geom = sr.shape.__geo_interface__

    if atr['_SPLAY'] ==0 :
        nodes = geom['coordinates']
        newnodes = []
        for node in nodes:
            x2,y2 = transformer.transform(node[0],node[1])

            newnodes.append((y2,x2))
        geom['coordinates'] =  newnodes

        SURVEY_LINES.append(dict(type="Feature", geometry=geom, properties=atr))

print(SURVEY_LINES)

#geojson = open("../data/gis/lines2D.js", "w")
#geojson.write("var lines2D = \n")
#geojson.write(dumps({"type": "FeatureCollection", "features": SURVEY_LINES}, indent=2) + "\n")
#geojson.close()
